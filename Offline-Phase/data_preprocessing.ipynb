# %% [markdown]
# ## Data Preprocessing of Bitola Dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/training/bitola_features.csv",low_memory=False)

# %%
df.head(30)
# Out:
#                                 sensorId                  timestamp    city  \
# 0   16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T01:13:38+01:00  bitola
# 1   16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T01:29:10+01:00  bitola
# 2   16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T01:44:41+01:00  bitola
# 3   16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T02:00:13+01:00  bitola
# 4   16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T02:15:45+01:00  bitola
# 5   16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T02:31:16+01:00  bitola
# 6   16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T02:46:48+01:00  bitola
# 7   16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T03:02:20+01:00  bitola
# 8   16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T03:17:52+01:00  bitola
# 9   16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T03:33:23+01:00  bitola
# 10  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T03:48:55+01:00  bitola
# 11  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T04:04:27+01:00  bitola
# 12  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T04:19:58+01:00  bitola
# 13  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T04:35:30+01:00  bitola
# 14  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T04:51:01+01:00  bitola
# 15  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T05:06:33+01:00  bitola
# 16  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T05:22:05+01:00  bitola
# 17  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T05:37:36+01:00  bitola
# 18  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T05:53:08+01:00  bitola
# 19  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T06:08:40+01:00  bitola
# 20  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T06:24:12+01:00  bitola
# 21  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T06:39:44+01:00  bitola
# 22  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T06:55:16+01:00  bitola
# 23  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T07:10:48+01:00  bitola
# 24  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T07:26:21+01:00  bitola
# 25  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T07:41:52+01:00  bitola
# 26  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T07:57:25+01:00  bitola
# 27  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T08:12:57+01:00  bitola
# 28  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T08:28:28+01:00  bitola
# 29  16836a55-7140-43e2-9a63-56fac5cba714  2023-12-01T08:44:00+01:00  bitola
#
#     co  humidity  no2  o3  pm10  pm25  pressure  ...  wind_speed  \
# 0  NaN      58.0  NaN NaN  16.0   7.0     943.0  ...         8.3
# 1  NaN      58.0  NaN NaN  34.0  16.0     943.0  ...         8.3
# 2  NaN      59.0  NaN NaN  35.0  18.0     943.0  ...         8.3
# 3  NaN      59.0  NaN NaN  26.0  10.0     943.0  ...         9.3
# 4  NaN      59.0  NaN NaN  15.0   7.0     943.0  ...         9.3
# 5  NaN      60.0  NaN NaN   5.0   2.0     943.0  ...         9.3
# 6  NaN      59.0  NaN NaN   9.0   1.0     943.0  ...         9.3
# 7  NaN      60.0  NaN NaN  11.0   6.0     943.0  ...         8.3
# 8  NaN      60.0  NaN NaN   9.0   3.0     943.0  ...         8.3
# 9  NaN      60.0  NaN NaN  10.0   5.0     942.0  ...         8.3
# 10 NaN      60.0  NaN NaN  10.0   4.0     942.0  ...         8.3
# 11 NaN      59.0  NaN NaN   8.0   4.0     942.0  ...         9.4
# 12 NaN      59.0  NaN NaN  13.0   6.0     942.0  ...         9.4
# 13 NaN      59.0  NaN NaN  13.0   6.0     942.0  ...         9.4
# 14 NaN      60.0  NaN NaN   5.0   2.0     942.0  ...         9.4
# 15 NaN      60.0  NaN NaN   5.0   2.0     942.0  ...         9.0
# 16 NaN      59.0  NaN NaN   4.0   1.0     942.0  ...         9.0
# 17 NaN      59.0  NaN NaN   3.0   1.0     942.0  ...         9.0
# 18 NaN      60.0  NaN NaN   8.0   4.0     942.0  ...         9.0
# 19 NaN      60.0  NaN NaN   4.0   2.0     942.0  ...         7.6
# 20 NaN      60.0  NaN NaN  16.0   7.0     942.0  ...         7.6
# 21 NaN      60.0  NaN NaN   9.0   4.0     942.0  ...         7.6
# 22 NaN      61.0  NaN NaN   7.0   3.0     942.0  ...         7.6
# 23 NaN      60.0  NaN NaN   3.0   1.0     942.0  ...         6.8
# 24 NaN      59.0  NaN NaN   3.0   1.0     942.0  ...         6.8
# 25 NaN      59.0  NaN NaN   5.0   3.0     942.0  ...         6.8
# 26 NaN      58.0  NaN NaN  21.0  10.0     942.0  ...         6.8
# 27 NaN      58.0  NaN NaN  30.0  15.0     943.0  ...        12.4
# 28 NaN      57.0  NaN NaN  15.0   8.0     943.0  ...        12.4
# 29 NaN      56.0  NaN NaN  11.0   3.0     943.0  ...        12.4
#
#     neighbor_1_pm10  neighbor_1_pm25  neighbor_1_wind_speed  neighbor_2_pm10  \
# 0               NaN              NaN                    NaN              NaN
# 1               NaN              NaN                    NaN              NaN
# 2               NaN              NaN                    NaN              NaN
# 3               NaN              NaN                    NaN              NaN
# 4               NaN              NaN                    NaN              NaN
# 5               NaN              NaN                    NaN              NaN
# 6               NaN              NaN                    NaN              NaN
# 7               NaN              NaN                    NaN              NaN
# 8               NaN              NaN                    NaN              NaN
# 9               NaN              NaN                    NaN              NaN
# 10              NaN              NaN                    NaN              NaN
# 11              NaN              NaN                    NaN              NaN
# 12              NaN              NaN                    NaN              NaN
# 13              NaN              NaN                    NaN              NaN
# 14              NaN              NaN                    NaN              NaN
# 15              NaN              NaN                    NaN              NaN
# 16              NaN              NaN                    NaN              NaN
# 17              NaN              NaN                    NaN              NaN
# 18              NaN              NaN                    NaN              NaN
# 19              NaN              NaN                    NaN              NaN
# 20              NaN              NaN                    NaN              NaN
# 21              NaN              NaN                    NaN              NaN
# 22              NaN              NaN                    NaN              NaN
# 23              NaN              NaN                    NaN              NaN
# 24              NaN              NaN                    NaN              NaN
# 25              NaN              NaN                    NaN              NaN
# 26              NaN              NaN                    NaN              NaN
# 27              NaN              NaN                    NaN              NaN
# 28              NaN              NaN                    NaN              NaN
# 29              NaN              NaN                    NaN              NaN
#
#     neighbor_2_pm25  neighbor_2_wind_speed  neighbor_3_pm10  neighbor_3_pm25  \
# 0               NaN                    NaN              NaN              NaN
# 1               NaN                    NaN              NaN              NaN
# 2               NaN                    NaN              NaN              NaN
# 3               NaN                    NaN              NaN              NaN
# 4               NaN                    NaN              NaN              NaN
# 5               NaN                    NaN              NaN              NaN
# 6               NaN                    NaN              NaN              NaN
# 7               NaN                    NaN              NaN              NaN
# 8               NaN                    NaN              NaN              NaN
# 9               NaN                    NaN              NaN              NaN
# 10              NaN                    NaN              NaN              NaN
# 11              NaN                    NaN              NaN              NaN
# 12              NaN                    NaN              NaN              NaN
# 13              NaN                    NaN              NaN              NaN
# 14              NaN                    NaN              NaN              NaN
# 15              NaN                    NaN              NaN              NaN
# 16              NaN                    NaN              NaN              NaN
# 17              NaN                    NaN              NaN              NaN
# 18              NaN                    NaN              NaN              NaN
# 19              NaN                    NaN              NaN              NaN
# 20              NaN                    NaN              NaN              NaN
# 21              NaN                    NaN              NaN              NaN
# 22              NaN                    NaN              NaN              NaN
# 23              NaN                    NaN              NaN              NaN
# 24              NaN                    NaN              NaN              NaN
# 25              NaN                    NaN              NaN              NaN
# 26              NaN                    NaN              NaN              NaN
# 27              NaN                    NaN              NaN              NaN
# 28              NaN                    NaN              NaN              NaN
# 29              NaN                    NaN              NaN              NaN
#
#     neighbor_3_wind_speed
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN
# 18                    NaN
# 19                    NaN
# 20                    NaN
# 21                    NaN
# 22                    NaN
# 23                    NaN
# 24                    NaN
# 25                    NaN
# 26                    NaN
# 27                    NaN
# 28                    NaN
# 29                    NaN
#
# [30 rows x 21 columns]

# %%
len(df)
# Out:
# 1103359

# %%
df.tail(10)
# Out:
#                                      sensorId                  timestamp  \
# 1103349  fec52a19-9148-4350-a1b4-ae0da05ee199  2025-11-30T23:22:38+01:00
# 1103350  fec52a19-9148-4350-a1b4-ae0da05ee199  2025-11-30T23:24:44+00:00
# 1103351  fec52a19-9148-4350-a1b4-ae0da05ee199  2025-11-30T23:38:10+01:00
# 1103352  fec52a19-9148-4350-a1b4-ae0da05ee199  2025-11-30T23:40:16+00:00
# 1103353  fec52a19-9148-4350-a1b4-ae0da05ee199  2025-11-30T23:53:41+01:00
# 1103354  fec52a19-9148-4350-a1b4-ae0da05ee199  2025-11-30T23:55:47+00:00
# 1103355  fec52a19-9148-4350-a1b4-ae0da05ee199  2025-12-01T00:09:13+01:00
# 1103356  fec52a19-9148-4350-a1b4-ae0da05ee199  2025-12-01T00:24:44+01:00
# 1103357  fec52a19-9148-4350-a1b4-ae0da05ee199  2025-12-01T00:40:16+01:00
# 1103358  fec52a19-9148-4350-a1b4-ae0da05ee199  2025-12-01T00:55:47+01:00
#
#            city  co  humidity  no2  o3  pm10  pm25  pressure  ...  wind_speed  \
# 1103349  bitola NaN      64.0  NaN NaN   3.0   2.0     943.0  ...         NaN
# 1103350  bitola NaN       NaN  NaN NaN   NaN   NaN       NaN  ...         6.2
# 1103351  bitola NaN      64.0  NaN NaN   4.0   4.0     943.0  ...         NaN
# 1103352  bitola NaN       NaN  NaN NaN   NaN   NaN       NaN  ...         6.2
# 1103353  bitola NaN      64.0  NaN NaN   3.0   2.0     943.0  ...         NaN
# 1103354  bitola NaN       NaN  NaN NaN   NaN   NaN       NaN  ...         6.2
# 1103355  bitola NaN      63.0  NaN NaN   3.0   1.0     943.0  ...         NaN
# 1103356  bitola NaN      64.0  NaN NaN   0.0   0.0     943.0  ...         NaN
# 1103357  bitola NaN      64.0  NaN NaN   3.0   1.0     943.0  ...         NaN
# 1103358  bitola NaN      64.0  NaN NaN   1.0   1.0     943.0  ...         NaN
#
#          neighbor_1_pm10  neighbor_1_pm25  neighbor_1_wind_speed  \
# 1103349              NaN              NaN                    NaN
# 1103350              NaN              NaN                    NaN
# 1103351              NaN              NaN                    NaN
# 1103352              NaN              NaN                    NaN
# 1103353              NaN              NaN                    NaN
# 1103354              NaN              NaN                    NaN
# 1103355              NaN              NaN                    NaN
# 1103356              NaN              NaN                    NaN
# 1103357              NaN              NaN                    NaN
# 1103358              NaN              NaN                    NaN
#
#          neighbor_2_pm10  neighbor_2_pm25  neighbor_2_wind_speed  \
# 1103349              NaN              NaN                    NaN
# 1103350              NaN              NaN                    NaN
# 1103351              NaN              NaN                    NaN
# 1103352              NaN              NaN                    NaN
# 1103353              NaN              NaN                    NaN
# 1103354              NaN              NaN                    NaN
# 1103355              NaN              NaN                    NaN
# 1103356              NaN              NaN                    NaN
# 1103357              NaN              NaN                    NaN
# 1103358              NaN              NaN                    NaN
#
#          neighbor_3_pm10  neighbor_3_pm25  neighbor_3_wind_speed
# 1103349              NaN              NaN                    NaN
# 1103350              NaN              NaN                    NaN
# 1103351              NaN              NaN                    NaN
# 1103352              NaN              NaN                    NaN
# 1103353              NaN              NaN                    NaN
# 1103354              NaN              NaN                    NaN
# 1103355              NaN              NaN                    NaN
# 1103356              NaN              NaN                    NaN
# 1103357              NaN              NaN                    NaN
# 1103358              NaN              NaN                    NaN
#
# [10 rows x 21 columns]

# %%
df.describe()
# Out:
#                  co       humidity           no2            o3           pm10  \
# count  24900.000000  508847.000000  25540.000000  21108.000000  526502.000000
# mean       0.238514      52.511991     12.215623     39.399754      26.018306
# std        0.603232      16.208122     12.427257     28.810507      55.757197
# min        0.000000       8.000000      0.000000      0.000000       0.000000
# 25%        0.000000      40.000000      3.000000     13.000000       5.000000
# 50%        0.000000      53.000000      8.000000     35.000000      10.000000
# 75%        0.000000      65.000000     17.000000     61.000000      23.000000
# max        8.000000      99.000000    124.000000    145.000000    1995.000000
#
#                 pm25       pressure    temperature     wind_speed  \
# count  538495.000000  510019.000000  510019.000000  562249.000000
# mean       13.641850     939.442499      16.849076       5.973859
# std        28.540954      14.724173       9.174995       3.812610
# min         0.000000     869.000000     -12.000000       0.000000
# 25%         2.000000     937.000000      10.000000       3.300000
# 50%         5.000000     942.000000      16.000000       5.200000
# 75%        12.000000     947.000000      24.000000       7.700000
# max       998.000000     975.000000      49.000000      32.800000
#
#        neighbor_1_pm10  neighbor_1_pm25  neighbor_1_wind_speed  \
# count       213.000000       213.000000             217.000000
# mean         32.399061        17.201878               7.502304
# std          78.899180        42.788440               4.416860
# min           0.000000         0.000000               0.000000
# 25%           5.000000         2.000000               4.200000
# 50%           8.000000         4.000000               6.600000
# 75%          17.000000        10.000000              10.600000
# max         632.000000       324.000000              23.400000
#
#        neighbor_2_pm10  neighbor_2_pm25  neighbor_2_wind_speed  \
# count       183.000000       183.000000             203.000000
# mean         29.349727        12.857923               5.952217
# std         117.788776        29.968876               3.442575
# min           1.000000         0.000000               0.400000
# 25%           4.000000         2.000000               3.300000
# 50%           7.000000         4.000000               5.400000
# 75%          20.000000        10.500000               8.400000
# max        1519.000000       287.000000              18.300000
#
#        neighbor_3_pm10  neighbor_3_pm25  neighbor_3_wind_speed
# count       297.000000       303.000000             306.000000
# mean         23.326599        11.557756               6.343137
# std          52.510402        26.146349               3.713277
# min           0.000000         0.000000               0.400000
# 25%           5.000000         2.500000               4.400000
# 50%           9.000000         4.000000               5.750000
# 75%          17.000000        10.000000               7.975000
# max         457.000000       238.000000              19.800000

# %%
percent_missing = (df.isnull().sum() * 100) / len(df)
print(percent_missing)
# Out:
# sensorId                  0.000000
# timestamp                 0.000000
# city                      0.000000
# co                       97.743255
# humidity                 53.882009
# no2                      97.685250
# o3                       98.086933
# pm10                     52.281896
# pm25                     51.194942
# pressure                 53.775788
# temperature              53.775788
# wind_speed               49.042062
# neighbor_1_pm10          99.980695
# neighbor_1_pm25          99.980695
# neighbor_1_wind_speed    99.980333
# neighbor_2_pm10          99.983414
# neighbor_2_pm25          99.983414
# neighbor_2_wind_speed    99.981602
# neighbor_3_pm10          99.973082
# neighbor_3_pm25          99.972538
# neighbor_3_wind_speed    99.972267
# dtype: float64

# %% [markdown]
# ### Drop the insignificant columns that has missing value percentage above 90%

# %%
df= df.drop(columns=['neighbor_1_pm10','neighbor_2_pm10','neighbor_3_pm10','neighbor_1_pm25','neighbor_2_pm25','neighbor_3_pm25','neighbor_1_wind_speed','neighbor_2_wind_speed','neighbor_3_wind_speed','no2','o3','co','city'],axis=1)

# %%
df.columns
# Out:
# Index(['sensorId', 'timestamp', 'humidity', 'pm10', 'pm25', 'pressure',
#        'temperature', 'wind_speed'],
#       dtype='object')

# %%
df['sensorId'].value_counts()
# Out:
# sensorId
# 40f081a6-4095-43f7-bffb-64e2af8c026e    128007
# 87f82783-853b-417d-8964-b5cf11e44873    127413
# 874ff9c6-786d-45fc-a90e-48c7ffe03417    125548
# 7b316592-8036-41e2-b8dc-b06b6a9afd54    122295
# 16836a55-7140-43e2-9a63-56fac5cba714    108369
# 2819ecbb-5de3-4092-aa1d-4ba3a8c40add     92896
# d7060523-b163-4cc3-bc94-970dac72a38a     83655
# 23b735ef-a996-4a7f-9998-2aa7e78827b0     73235
# d241a044-0a06-40c2-9d90-c91fd0a95060     70704
# fec52a19-9148-4350-a1b4-ae0da05ee199     70546
# 2002                                     30192
# 2001                                     29574
# d851c0b9-990e-41db-9c53-529f88524cf9     16562
# e20e9778-a020-4b86-932a-b7ab6a713a00     16017
# 30dab8a6-ff63-43ce-9a3b-99f1f3f7054d      8342
# 87f82783-853b-417d-8964-b5cf11e44872         2
# a9a2083f-f086-4fae-bdae-355b391f436b         1
# d851c0b9-990e-41db-9c53-529f88524cf8         1
# Name: count, dtype: int64

# %%
print(df['timestamp'].min())
print(df['timestamp'].max())
# Out:
# 2023-12-01T01:00:13+01:00
# 2025-12-01T00:59:34+01:00

# %%
df['sensorId'].nunique()
# Out:
# 18

# %% [markdown]
# ### Convert the original timestamp into hourly timestamp

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"], utc=True)


df["timestamp"] = df["timestamp"].dt.floor("h")

# %%
df.head(30)
# Out:
#                                 sensorId                 timestamp  humidity  \
# 0   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 00:00:00+00:00      58.0
# 1   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 00:00:00+00:00      58.0
# 2   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 00:00:00+00:00      59.0
# 3   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 01:00:00+00:00      59.0
# 4   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 01:00:00+00:00      59.0
# 5   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 01:00:00+00:00      60.0
# 6   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 01:00:00+00:00      59.0
# 7   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 02:00:00+00:00      60.0
# 8   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 02:00:00+00:00      60.0
# 9   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 02:00:00+00:00      60.0
# 10  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 02:00:00+00:00      60.0
# 11  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 03:00:00+00:00      59.0
# 12  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 03:00:00+00:00      59.0
# 13  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 03:00:00+00:00      59.0
# 14  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 03:00:00+00:00      60.0
# 15  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 04:00:00+00:00      60.0
# 16  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 04:00:00+00:00      59.0
# 17  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 04:00:00+00:00      59.0
# 18  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 04:00:00+00:00      60.0
# 19  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 05:00:00+00:00      60.0
# 20  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 05:00:00+00:00      60.0
# 21  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 05:00:00+00:00      60.0
# 22  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 05:00:00+00:00      61.0
# 23  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 06:00:00+00:00      60.0
# 24  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 06:00:00+00:00      59.0
# 25  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 06:00:00+00:00      59.0
# 26  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 06:00:00+00:00      58.0
# 27  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 07:00:00+00:00      58.0
# 28  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 07:00:00+00:00      57.0
# 29  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 07:00:00+00:00      56.0
#
#     pm10  pm25  pressure  temperature  wind_speed
# 0   16.0   7.0     943.0         12.0         8.3
# 1   34.0  16.0     943.0         12.0         8.3
# 2   35.0  18.0     943.0         12.0         8.3
# 3   26.0  10.0     943.0         12.0         9.3
# 4   15.0   7.0     943.0         12.0         9.3
# 5    5.0   2.0     943.0         12.0         9.3
# 6    9.0   1.0     943.0         12.0         9.3
# 7   11.0   6.0     943.0         12.0         8.3
# 8    9.0   3.0     943.0         12.0         8.3
# 9   10.0   5.0     942.0         12.0         8.3
# 10  10.0   4.0     942.0         13.0         8.3
# 11   8.0   4.0     942.0         13.0         9.4
# 12  13.0   6.0     942.0         13.0         9.4
# 13  13.0   6.0     942.0         13.0         9.4
# 14   5.0   2.0     942.0         13.0         9.4
# 15   5.0   2.0     942.0         13.0         9.0
# 16   4.0   1.0     942.0         13.0         9.0
# 17   3.0   1.0     942.0         13.0         9.0
# 18   8.0   4.0     942.0         13.0         9.0
# 19   4.0   2.0     942.0         13.0         7.6
# 20  16.0   7.0     942.0         13.0         7.6
# 21   9.0   4.0     942.0         13.0         7.6
# 22   7.0   3.0     942.0         13.0         7.6
# 23   3.0   1.0     942.0         13.0         6.8
# 24   3.0   1.0     942.0         14.0         6.8
# 25   5.0   3.0     942.0         14.0         6.8
# 26  21.0  10.0     942.0         14.0         6.8
# 27  30.0  15.0     943.0         15.0        12.4
# 28  15.0   8.0     943.0         15.0        12.4
# 29  11.0   3.0     943.0         16.0        12.4

# %% [markdown]
# ### Hourly aggregation grouped by sensorId and timestamp

# %%
df_hourly = (
    df.groupby(["sensorId", "timestamp"])
      .agg({
          "humidity":"mean",
          "pm10":"mean",
          "pm25":"mean",
          "pressure":"mean",
          "temperature":"mean",
          "wind_speed":"mean"
      })
      .reset_index()
)

# %%
df_hourly = df_hourly.sort_values(by=["timestamp", "sensorId"]).reset_index(drop=True)

# %%
df_hourly.head(20)
# Out:
#                                 sensorId                 timestamp   humidity  \
# 0   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 00:00:00+00:00  58.333333
# 1                                   2001 2023-12-01 00:00:00+00:00        NaN
# 2                                   2002 2023-12-01 00:00:00+00:00        NaN
# 3   40f081a6-4095-43f7-bffb-64e2af8c026e 2023-12-01 00:00:00+00:00  61.000000
# 4   874ff9c6-786d-45fc-a90e-48c7ffe03417 2023-12-01 00:00:00+00:00  68.250000
# 5   87f82783-853b-417d-8964-b5cf11e44873 2023-12-01 00:00:00+00:00  67.000000
# 6   d851c0b9-990e-41db-9c53-529f88524cf8 2023-12-01 00:00:00+00:00        NaN
# 7   d851c0b9-990e-41db-9c53-529f88524cf9 2023-12-01 00:00:00+00:00  61.000000
# 8   e20e9778-a020-4b86-932a-b7ab6a713a00 2023-12-01 00:00:00+00:00  47.000000
# 9   16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 01:00:00+00:00  59.250000
# 10                                  2001 2023-12-01 01:00:00+00:00        NaN
# 11                                  2002 2023-12-01 01:00:00+00:00        NaN
# 12  40f081a6-4095-43f7-bffb-64e2af8c026e 2023-12-01 01:00:00+00:00  62.500000
# 13  874ff9c6-786d-45fc-a90e-48c7ffe03417 2023-12-01 01:00:00+00:00  69.500000
# 14  87f82783-853b-417d-8964-b5cf11e44873 2023-12-01 01:00:00+00:00  67.750000
# 15  d851c0b9-990e-41db-9c53-529f88524cf9 2023-12-01 01:00:00+00:00  62.500000
# 16  e20e9778-a020-4b86-932a-b7ab6a713a00 2023-12-01 01:00:00+00:00  48.666667
# 17  16836a55-7140-43e2-9a63-56fac5cba714 2023-12-01 02:00:00+00:00  60.000000
# 18                                  2001 2023-12-01 02:00:00+00:00        NaN
# 19                                  2002 2023-12-01 02:00:00+00:00        NaN
#
#          pm10       pm25  pressure  temperature  wind_speed
# 0   28.333333  13.666667     943.0        12.00         8.3
# 1         NaN   9.000000       NaN          NaN         8.3
# 2         NaN  27.000000       NaN          NaN         8.3
# 3    5.500000   3.000000     942.0        12.00         5.0
# 4   10.750000   3.500000     940.0        10.75         5.0
# 5   52.000000  25.500000     943.0        11.00         8.3
# 6         NaN        NaN       NaN          NaN         5.0
# 7   11.000000   6.000000     935.0        10.00         NaN
# 8   28.750000  16.000000     944.0        16.00         8.3
# 9   13.750000   5.000000     943.0        12.00         9.3
# 10        NaN  10.000000       NaN          NaN         9.3
# 11  27.000000  23.000000       NaN          NaN         9.3
# 12   7.250000   3.250000     942.0        12.00         4.8
# 13   9.250000   2.250000     940.0        11.00         4.8
# 14  69.750000  29.500000     943.0        11.00         9.3
# 15   7.000000   2.500000     935.0        10.00         4.8
# 16  23.666667  12.333333     944.0        16.00         9.3
# 17  10.000000   4.500000     942.5        12.25         8.3
# 18        NaN   8.000000       NaN          NaN         8.3
# 19  19.000000  16.000000       NaN          NaN         8.3

# %%
df_hourly['sensorId'].value_counts()
# Out:
# sensorId
# 40f081a6-4095-43f7-bffb-64e2af8c026e    17338
# 87f82783-853b-417d-8964-b5cf11e44873    17087
# 874ff9c6-786d-45fc-a90e-48c7ffe03417    16834
# 7b316592-8036-41e2-b8dc-b06b6a9afd54    16232
# 2002                                    15516
# 2001                                    15173
# 16836a55-7140-43e2-9a63-56fac5cba714    15021
# 2819ecbb-5de3-4092-aa1d-4ba3a8c40add    12040
# d7060523-b163-4cc3-bc94-970dac72a38a    10931
# 23b735ef-a996-4a7f-9998-2aa7e78827b0     9538
# d241a044-0a06-40c2-9d90-c91fd0a95060     9309
# fec52a19-9148-4350-a1b4-ae0da05ee199     9238
# e20e9778-a020-4b86-932a-b7ab6a713a00     2526
# d851c0b9-990e-41db-9c53-529f88524cf9     2360
# 30dab8a6-ff63-43ce-9a3b-99f1f3f7054d     1167
# 87f82783-853b-417d-8964-b5cf11e44872        2
# d851c0b9-990e-41db-9c53-529f88524cf8        1
# a9a2083f-f086-4fae-bdae-355b391f436b        1
# Name: count, dtype: int64

# %%
percent_missing = (df_hourly.isnull().sum() * 100) / len(df_hourly)
print(percent_missing)
# Out:
# sensorId        0.000000
# timestamp       0.000000
# humidity       21.429242
# pm10           11.738319
# pm25            4.716582
# pressure       21.323555
# temperature    21.323555
# wind_speed      0.002349
# dtype: float64

# %%
len(df_hourly)
# Out:
# 170314

# %%
sensor_stats = df_hourly.groupby('sensorId')[['humidity', 'pressure', 'pm10','pm25','temperature']].apply(lambda x: x.isnull().mean())

# %%
print(sensor_stats[sensor_stats['humidity'] > 0.9])
# Out:
#                                       humidity  pressure      pm10      pm25  \
# sensorId
# 2001                                       1.0       1.0  0.874448  0.113425
# 2002                                       1.0       1.0  0.157515  0.131026
# 87f82783-853b-417d-8964-b5cf11e44872       1.0       1.0  1.000000  1.000000
# d851c0b9-990e-41db-9c53-529f88524cf8       1.0       1.0  1.000000  1.000000
#
#                                       temperature
# sensorId
# 2001                                          1.0
# 2002                                          1.0
# 87f82783-853b-417d-8964-b5cf11e44872          1.0
# d851c0b9-990e-41db-9c53-529f88524cf8          1.0

# %% [markdown]
# ### Remove the sensors that have 100% missing values for pm10 and pm25

# %%
sensor_stats = df_hourly.groupby('sensorId')[['pm10', 'pm25']].count()
valid_sensors = sensor_stats[sensor_stats.sum(axis=1) > 0].index

df_hourly = df_hourly[df_hourly['sensorId'].isin(valid_sensors)]

# %%
len(df_hourly)
# Out:
# 170311

# %%
df_hourly['sensorId'].value_counts()
# Out:
# sensorId
# 40f081a6-4095-43f7-bffb-64e2af8c026e    17338
# 87f82783-853b-417d-8964-b5cf11e44873    17087
# 874ff9c6-786d-45fc-a90e-48c7ffe03417    16834
# 7b316592-8036-41e2-b8dc-b06b6a9afd54    16232
# 2002                                    15516
# 2001                                    15173
# 16836a55-7140-43e2-9a63-56fac5cba714    15021
# 2819ecbb-5de3-4092-aa1d-4ba3a8c40add    12040
# d7060523-b163-4cc3-bc94-970dac72a38a    10931
# 23b735ef-a996-4a7f-9998-2aa7e78827b0     9538
# d241a044-0a06-40c2-9d90-c91fd0a95060     9309
# fec52a19-9148-4350-a1b4-ae0da05ee199     9238
# e20e9778-a020-4b86-932a-b7ab6a713a00     2526
# d851c0b9-990e-41db-9c53-529f88524cf9     2360
# 30dab8a6-ff63-43ce-9a3b-99f1f3f7054d     1167
# a9a2083f-f086-4fae-bdae-355b391f436b        1
# Name: count, dtype: int64

# %% [markdown]
# ### Remove the sparse sensor

# %%
df_hourly = df_hourly[df_hourly['sensorId']!="a9a2083f-f086-4fae-bdae-355b391f436b"]

# %%
percent_missing = (df_hourly.isnull().sum() * 100) / len(df_hourly)
print(percent_missing)
# Out:
# sensorId        0.000000
# timestamp       0.000000
# humidity       21.427984
# pm10           11.736833
# pm25            4.714932
# pressure       21.322295
# temperature    21.322295
# wind_speed      0.001761
# dtype: float64

# %%
df_hourly['sensorId'].value_counts()
# Out:
# sensorId
# 40f081a6-4095-43f7-bffb-64e2af8c026e    17338
# 87f82783-853b-417d-8964-b5cf11e44873    17087
# 874ff9c6-786d-45fc-a90e-48c7ffe03417    16834
# 7b316592-8036-41e2-b8dc-b06b6a9afd54    16232
# 2002                                    15516
# 2001                                    15173
# 16836a55-7140-43e2-9a63-56fac5cba714    15021
# 2819ecbb-5de3-4092-aa1d-4ba3a8c40add    12040
# d7060523-b163-4cc3-bc94-970dac72a38a    10931
# 23b735ef-a996-4a7f-9998-2aa7e78827b0     9538
# d241a044-0a06-40c2-9d90-c91fd0a95060     9309
# fec52a19-9148-4350-a1b4-ae0da05ee199     9238
# e20e9778-a020-4b86-932a-b7ab6a713a00     2526
# d851c0b9-990e-41db-9c53-529f88524cf9     2360
# 30dab8a6-ff63-43ce-9a3b-99f1f3f7054d     1167
# Name: count, dtype: int64

# %%
start = df_hourly['timestamp'].min()
end = df_hourly['timestamp'].max()
print(f"Start: {start}")
print(f"End: {end}")
# Out:
# Start: 2023-12-01 00:00:00+00:00
# End: 2025-11-30 23:00:00+00:00

# %% [markdown]
# ### Add the full timeframe for each sensor

# %%
processed_dfs = []
for sensor_id, group in df_hourly.groupby('sensorId'):
    group = group.sort_values('timestamp').set_index('timestamp')
    group = group.resample('h').asfreq().reindex(pd.date_range(start, end, freq='h'))
    group['sensorId'] = sensor_id
    processed_dfs.append(group.reset_index())

df_hourly_full = pd.concat(processed_dfs)

# %%
df_hourly_full = df_hourly_full.rename(columns={'index': 'timestamp'})

# %%
df_hourly_full.columns
# Out:
# Index(['timestamp', 'sensorId', 'humidity', 'pm10', 'pm25', 'pressure',
#        'temperature', 'wind_speed'],
#       dtype='object')

# %%
df_hourly_full['sensorId'].value_counts()
# Out:
# sensorId
# 16836a55-7140-43e2-9a63-56fac5cba714    17544
# 2001                                    17544
# 2002                                    17544
# 23b735ef-a996-4a7f-9998-2aa7e78827b0    17544
# 2819ecbb-5de3-4092-aa1d-4ba3a8c40add    17544
# 30dab8a6-ff63-43ce-9a3b-99f1f3f7054d    17544
# 40f081a6-4095-43f7-bffb-64e2af8c026e    17544
# 7b316592-8036-41e2-b8dc-b06b6a9afd54    17544
# 874ff9c6-786d-45fc-a90e-48c7ffe03417    17544
# 87f82783-853b-417d-8964-b5cf11e44873    17544
# d241a044-0a06-40c2-9d90-c91fd0a95060    17544
# d7060523-b163-4cc3-bc94-970dac72a38a    17544
# d851c0b9-990e-41db-9c53-529f88524cf9    17544
# e20e9778-a020-4b86-932a-b7ab6a713a00    17544
# fec52a19-9148-4350-a1b4-ae0da05ee199    17544
# Name: count, dtype: int64

# %%
percent_missing = (df_hourly_full.isnull().sum() * 100) / len(df_hourly)
print(percent_missing)
# Out:
# timestamp       0.000000
# sensorId        0.000000
# humidity       75.946216
# pm10           66.255064
# pm25           59.233163
# pressure       75.840526
# temperature    75.840526
# wind_speed     54.519993
# dtype: float64

# %% [markdown]
# ### Linear Interpolation process for filling small gaps

# %%
df_hourly_full = df_hourly_full.sort_values(['sensorId', 'timestamp'])

cols_to_fix = ['temperature', 'humidity', 'pressure', 'wind_speed']

for col in cols_to_fix:

    df_hourly_full[col] = df_hourly_full.groupby('sensorId')[col].transform(
        lambda x: x.interpolate(method='linear', limit=3)
    )

# %%
percent_missing = (df_hourly_full.isnull().sum() * 100) / len(df_hourly_full)
print(percent_missing)
# Out:
# timestamp       0.000000
# sensorId        0.000000
# humidity       48.582611
# pm10           42.878477
# pm25           38.334093
# pressure       48.548792
# temperature    48.548792
# wind_speed     33.636571
# dtype: float64

# %%
len(df_hourly_full)
# Out:
# 263160

# %%
sensor_stats = df_hourly_full.groupby('sensorId')[['humidity', 'pressure', 'pm10','pm25','temperature']].apply(lambda x: x.isnull().mean())
print(sensor_stats[sensor_stats['humidity'] > 0.5])
# Out:
#                                       humidity  pressure      pm10      pm25  \
# sensorId
# 2001                                  1.000000  1.000000  0.891416  0.233242
# 2002                                  1.000000  1.000000  0.254902  0.231475
# 30dab8a6-ff63-43ce-9a3b-99f1f3f7054d  0.929264  0.929264  0.933539  0.933539
# d851c0b9-990e-41db-9c53-529f88524cf9  0.865481  0.864626  0.871808  0.871808
# e20e9778-a020-4b86-932a-b7ab6a713a00  0.883493  0.883493  0.856019  0.856019
#
#                                       temperature
# sensorId
# 2001                                     1.000000
# 2002                                     1.000000
# 30dab8a6-ff63-43ce-9a3b-99f1f3f7054d     0.929264
# d851c0b9-990e-41db-9c53-529f88524cf9     0.864626
# e20e9778-a020-4b86-932a-b7ab6a713a00     0.883493

# %% [markdown]
# ### Remove again the sensors that have high percentage of missing values for pm10 and pm25

# %%
sensors_to_keep = sensor_stats[(sensor_stats['pm10'] <= 0.8) & (sensor_stats['pm25'] <= 0.8)].index

df_hourly_full = df_hourly_full[df_hourly_full['sensorId'].isin(sensors_to_keep)]

# %%
df_hourly_full['sensorId'].value_counts()
# Out:
# sensorId
# 16836a55-7140-43e2-9a63-56fac5cba714    17544
# 2002                                    17544
# 23b735ef-a996-4a7f-9998-2aa7e78827b0    17544
# 2819ecbb-5de3-4092-aa1d-4ba3a8c40add    17544
# 40f081a6-4095-43f7-bffb-64e2af8c026e    17544
# 7b316592-8036-41e2-b8dc-b06b6a9afd54    17544
# 874ff9c6-786d-45fc-a90e-48c7ffe03417    17544
# 87f82783-853b-417d-8964-b5cf11e44873    17544
# d241a044-0a06-40c2-9d90-c91fd0a95060    17544
# d7060523-b163-4cc3-bc94-970dac72a38a    17544
# fec52a19-9148-4350-a1b4-ae0da05ee199    17544
# Name: count, dtype: int64

# %%
percent_missing = (df_hourly_full.isnull().sum() * 100) / len(df_hourly_full)
print(percent_missing)
# Out:
# timestamp       0.000000
# sensorId        0.000000
# humidity       32.810492
# pm10           26.172636
# pm25           25.959147
# pressure       32.772147
# temperature    32.772147
# wind_speed     21.399183
# dtype: float64

# %% [markdown]
# ### Fill missing weather with the average of all other sensors in Bitola for that specific hour

# %%
weather_cols = ['humidity', 'pressure', 'temperature', 'wind_speed']

df_hourly_full[weather_cols] = df_hourly_full[weather_cols].fillna(
    df_hourly_full.groupby('timestamp')[weather_cols].transform('mean')
)

# %%
percent_missing = (df_hourly_full.isnull().sum() * 100) / len(df_hourly_full)
print(percent_missing)
# Out:
# timestamp       0.000000
# sensorId        0.000000
# humidity        0.233698
# pm10           26.172636
# pm25           25.959147
# pressure        0.233698
# temperature     0.233698
# wind_speed      0.039900
# dtype: float64

# %%
df_hourly_full.head(20)
# Out:
#                    timestamp                              sensorId   humidity  \
# 0  2023-12-01 00:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  58.333333
# 1  2023-12-01 01:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.250000
# 2  2023-12-01 02:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  60.000000
# 3  2023-12-01 03:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.250000
# 4  2023-12-01 04:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.500000
# 5  2023-12-01 05:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  60.250000
# 6  2023-12-01 06:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.000000
# 7  2023-12-01 07:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  56.500000
# 8  2023-12-01 08:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  53.666667
# 9  2023-12-01 09:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  51.500000
# 10 2023-12-01 10:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  46.750000
# 11 2023-12-01 11:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  42.000000
# 12 2023-12-01 12:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  41.750000
# 13 2023-12-01 13:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  42.500000
# 14 2023-12-01 14:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  44.333333
# 15 2023-12-01 15:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  46.250000
# 16 2023-12-01 16:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  48.250000
# 17 2023-12-01 17:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  49.500000
# 18 2023-12-01 18:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  49.250000
# 19 2023-12-01 19:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  52.750000
#
#          pm10       pm25  pressure  temperature  wind_speed
# 0   28.333333  13.666667    943.00    12.000000         8.3
# 1   13.750000   5.000000    943.00    12.000000         9.3
# 2   10.000000   4.500000    942.50    12.250000         8.3
# 3    9.750000   4.500000    942.00    13.000000         9.4
# 4    5.000000   2.000000    942.00    13.000000         9.0
# 5    9.000000   4.000000    942.00    13.000000         7.6
# 6    8.000000   3.750000    942.00    13.750000         6.8
# 7   15.500000   7.000000    943.00    15.500000        12.4
# 8    7.333333   2.333333    943.00    16.666667        15.6
# 9    6.500000   1.750000    943.00    17.250000        18.6
# 10        NaN        NaN    942.50    18.125000        18.4
# 11   4.000000   1.000000    942.00    19.000000        18.2
# 12   7.000000   1.250000    941.75    19.500000        18.3
# 13  13.500000   1.250000    941.00    19.750000        17.6
# 14   6.000000   1.333333    941.00    19.000000        15.0
# 15   7.000000   1.500000    941.00    18.500000        12.6
# 16  10.250000   1.500000    941.00    18.000000        12.6
# 17  16.250000   2.250000    941.00    17.500000        10.4
# 18  11.666667   1.666667    941.00    17.000000         9.7
# 19  12.000000   2.500000    941.00    16.500000         9.4

# %%
df_hourly_full.describe()
# Out:
#             humidity          pm10           pm25       pressure  \
# count  192533.000000  142475.00000  142887.000000  192533.000000
# mean       52.706427      26.40624      14.096921     939.802395
# std        15.739595      49.61000      26.306709      12.804769
# min         9.500000       0.00000       0.000000     869.000000
# 25%        40.750000       5.25000       2.250000     937.000000
# 50%        53.562500      10.75000       5.500000     942.000000
# 75%        64.937500      26.00000      14.000000     946.000000
# max        99.000000    1995.00000     639.250000     971.750000
#
#          temperature     wind_speed
# count  192533.000000  192907.000000
# mean       16.796424       6.075865
# std         9.168444       3.743897
# min       -12.000000       0.000000
# 25%         9.666667       3.500000
# 50%        16.000000       5.300000
# 75%        23.750000       7.744444
# max        47.500000      32.800000

# %%
len(df_hourly_full)
# Out:
# 192984

# %%
df_hourly_full['sensorId'].value_counts()
# Out:
# sensorId
# 16836a55-7140-43e2-9a63-56fac5cba714    17544
# 2002                                    17544
# 23b735ef-a996-4a7f-9998-2aa7e78827b0    17544
# 2819ecbb-5de3-4092-aa1d-4ba3a8c40add    17544
# 40f081a6-4095-43f7-bffb-64e2af8c026e    17544
# 7b316592-8036-41e2-b8dc-b06b6a9afd54    17544
# 874ff9c6-786d-45fc-a90e-48c7ffe03417    17544
# 87f82783-853b-417d-8964-b5cf11e44873    17544
# d241a044-0a06-40c2-9d90-c91fd0a95060    17544
# d7060523-b163-4cc3-bc94-970dac72a38a    17544
# fec52a19-9148-4350-a1b4-ae0da05ee199    17544
# Name: count, dtype: int64

# %% [markdown]
# ### Load the neighborhood matrix of distances

# %%
neighbourhood_matrix = pd.read_csv("../data/neighbors_data/bitola_sensor_distances.csv")
neighbourhood_matrix
# Out:
#                                 sensor_id  \
# 0    d241a044-0a06-40c2-9d90-c91fd0a95060
# 1    fec52a19-9148-4350-a1b4-ae0da05ee199
# 2    d241a044-0a06-40c2-9d90-c91fd0a95060
# 3    be427cee-4c3a-4aa2-a1ce-9795a74533be
# 4    d241a044-0a06-40c2-9d90-c91fd0a95060
# ..                                    ...
# 457  7b316592-8036-41e2-b8dc-b06b6a9afd54
# 458  40f081a6-4095-43f7-bffb-64e2af8c026e
# 459  692c454c-a1ad-41fa-b3ca-aa1cb7d55d30
# 460  7b316592-8036-41e2-b8dc-b06b6a9afd54
# 461  692c454c-a1ad-41fa-b3ca-aa1cb7d55d30
#
#                               neighbor_id  distance_km
# 0    fec52a19-9148-4350-a1b4-ae0da05ee199     7.082000
# 1    d241a044-0a06-40c2-9d90-c91fd0a95060     7.082000
# 2    be427cee-4c3a-4aa2-a1ce-9795a74533be     8.838588
# 3    d241a044-0a06-40c2-9d90-c91fd0a95060     8.838588
# 4    c3f3da9b-9fd3-4037-94d3-598d655e6be9    10.004966
# ..                                    ...          ...
# 457  40f081a6-4095-43f7-bffb-64e2af8c026e     1.049671
# 458  692c454c-a1ad-41fa-b3ca-aa1cb7d55d30     3.044465
# 459  40f081a6-4095-43f7-bffb-64e2af8c026e     3.044465
# 460  692c454c-a1ad-41fa-b3ca-aa1cb7d55d30     2.083640
# 461  7b316592-8036-41e2-b8dc-b06b6a9afd54     2.083640
#
# [462 rows x 3 columns]

# %%
valid_sensors = df_hourly_full['sensorId'].unique()

# %%
neighbors_df_clean = neighbourhood_matrix[
    (neighbourhood_matrix['sensor_id'].isin(valid_sensors)) &
    (neighbourhood_matrix['neighbor_id'].isin(valid_sensors))
].copy()

# %% [markdown]
# ### Function for appending neighborhood features in each sensor

# %%
def append_neighbors(df_hourly, neighbors_df, weather_cols, k_search=20, k_keep=3):
    # 1. Standardize the neighbor list
    # Ensure we only take the top K based on distance
    neighbors_topk = (
        neighbors_df.sort_values(["sensor_id", "distance_km"])
        .groupby("sensor_id")
        .head(k_search)
        .copy()
    )

    # Track original distance rank
    neighbors_topk['dist_rank'] = neighbors_topk.groupby("sensor_id").cumcount() + 1

    # 2. Merge with main data
    # We use 'neighbor_id' from the matrix to match 'sensorId' in the hourly data
    neighbor_values = neighbors_topk.merge(
        df_hourly[['sensorId', 'timestamp'] + weather_cols],
        left_on='neighbor_id',
        right_on='sensorId',
        how='inner'
    )

    # 3. Filter for availability
    # The 'sensor_id' here is the ORIGINAL sensor we are finding neighbors for
    available_topk = (
        neighbor_values.sort_values(['sensor_id', 'timestamp', 'dist_rank'])
        .groupby(['sensor_id', 'timestamp'])
        .head(k_keep)
        .copy()
    )

    # Create the 1, 2, 3 rank for the wide-format columns
    available_topk['final_rank'] = available_topk.groupby(['sensor_id', 'timestamp']).cumcount() + 1

    # 4. Pivot to wide format
    pivot_df = available_topk.pivot(
        index=['sensor_id', 'timestamp'],
        columns='final_rank',
        values=weather_cols
    )

    # Clean up column names: neighbor1_temp, neighbor2_temp, etc.
    if isinstance(pivot_df.columns, pd.MultiIndex):
        pivot_df.columns = [f"neighbor{rank}_{col}" for col, rank in pivot_df.columns]
    else:
        # Handle case with only one weather column
        pivot_df.columns = [f"neighbor{i}_{weather_cols[0]}" for i in pivot_df.columns]

    pivot_df = pivot_df.reset_index()

    # 5. Final Join back to original data
    df_result = df_hourly.merge(
        pivot_df,
        left_on=['sensorId', 'timestamp'],
        right_on=['sensor_id', 'timestamp'],
        how='left'
    ).drop(columns=['sensor_id'])

    return df_result

# %%
weather_cols
# Out:
# ['humidity', 'pressure', 'temperature', 'wind_speed']

# %%
df_final = append_neighbors(df_hourly_full,neighbors_df_clean, weather_cols)

# %%
df_final
# Out:
#                        timestamp                              sensorId  \
# 0      2023-12-01 00:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 1      2023-12-01 01:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 2      2023-12-01 02:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 3      2023-12-01 03:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 4      2023-12-01 04:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# ...                          ...                                   ...
# 192979 2025-11-30 19:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 192980 2025-11-30 20:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 192981 2025-11-30 21:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 192982 2025-11-30 22:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 192983 2025-11-30 23:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
#
#          humidity       pm10       pm25  pressure  temperature  wind_speed  \
# 0       58.333333  28.333333  13.666667     943.0        12.00         8.3
# 1       59.250000  13.750000   5.000000     943.0        12.00         9.3
# 2       60.000000  10.000000   4.500000     942.5        12.25         8.3
# 3       59.250000   9.750000   4.500000     942.0        13.00         9.4
# 4       59.500000   5.000000   2.000000     942.0        13.00         9.0
# ...           ...        ...        ...       ...          ...         ...
# 192979  61.750000  11.250000   6.000000     942.0         9.00         5.9
# 192980  63.250000   9.000000   5.666667     942.0         9.00         5.7
# 192981  63.500000  12.000000   6.000000     942.5         8.25         5.8
# 192982  63.750000   3.250000   2.500000     943.0         7.75         5.6
# 192983  63.750000   1.750000   0.750000     943.0         7.00         6.2
#
#         neighbor1_humidity  neighbor2_humidity  neighbor3_humidity  \
# 0                63.645833           63.645833           63.645833
# 1                64.750000           64.750000           64.750000
# 2                65.312500           65.312500           65.312500
# 3                64.854167           64.854167           64.854167
# 4                65.062500           65.062500           65.062500
# ...                    ...                 ...                 ...
# 192979           63.500000           86.500000           68.583333
# 192980           63.750000           90.500000           69.333333
# 192981           63.333333           94.333333           70.425926
# 192982           63.750000           98.000000           70.888889
# 192983           64.000000           98.000000           71.472222
#
#         neighbor1_pressure  neighbor2_pressure  neighbor3_pressure  \
# 0               942.000000          942.000000          942.000000
# 1               942.000000          942.000000          942.000000
# 2               941.812500          941.812500          941.812500
# 3               941.166667          941.166667          941.166667
# 4               941.125000          941.125000          941.125000
# ...                    ...                 ...                 ...
# 192979          942.250000          940.000000          934.444444
# 192980          943.000000          940.000000          934.833333
# 192981          943.000000          940.000000          935.000000
# 192982          943.000000          941.000000          935.333333
# 192983          943.250000          941.000000          935.472222
#
#         neighbor1_temperature  neighbor2_temperature  neighbor3_temperature  \
# 0                   11.437500              11.437500              11.437500
# 1                   11.500000              11.500000              11.500000
# 2                   11.625000              11.625000              11.625000
# 3                   12.166667              12.166667              12.166667
# 4                   12.312500              12.312500              12.312500
# ...                       ...                    ...                    ...
# 192979               9.000000               6.500000               8.277778
# 192980               9.000000               6.000000               7.777778
# 192981               9.000000               6.666667               7.685185
# 192982               8.250000               6.250000               7.222222
# 192983               8.000000               6.000000               6.750000
#
#         neighbor1_wind_speed  neighbor2_wind_speed  neighbor3_wind_speed
# 0                       6.98                   8.3                  6.98
# 1                       7.50                   9.3                  7.50
# 2                       6.74                   8.3                  6.74
# 3                       7.84                   9.4                  7.84
# 4                       8.32                   9.0                  8.32
# ...                      ...                   ...                   ...
# 192979                  5.30                   5.9                  5.30
# 192980                  5.40                   5.7                  5.40
# 192981                  5.40                   5.8                  5.40
# 192982                  5.00                   5.6                  5.00
# 192983                  4.90                   6.2                  4.90
#
# [192984 rows x 20 columns]

# %%
percent_missing = (df_final.isnull().sum() * 100) / len(df_final)
print(percent_missing)
# Out:
# timestamp                 0.000000
# sensorId                  0.000000
# humidity                  0.233698
# pm10                     26.172636
# pm25                     25.959147
# pressure                  0.233698
# temperature               0.233698
# wind_speed                0.039900
# neighbor1_humidity        0.233698
# neighbor2_humidity        0.233698
# neighbor3_humidity        0.233698
# neighbor1_pressure        0.233698
# neighbor2_pressure        0.233698
# neighbor3_pressure        0.233698
# neighbor1_temperature     0.233698
# neighbor2_temperature     0.233698
# neighbor3_temperature     0.233698
# neighbor1_wind_speed      0.039900
# neighbor2_wind_speed      0.039900
# neighbor3_wind_speed      0.039900
# dtype: float64

# %%
len(df_final)
# Out:
# 192984

# %%
df_final['sensorId'].value_counts()
# Out:
# sensorId
# 16836a55-7140-43e2-9a63-56fac5cba714    17544
# 2002                                    17544
# 23b735ef-a996-4a7f-9998-2aa7e78827b0    17544
# 2819ecbb-5de3-4092-aa1d-4ba3a8c40add    17544
# 40f081a6-4095-43f7-bffb-64e2af8c026e    17544
# 7b316592-8036-41e2-b8dc-b06b6a9afd54    17544
# 874ff9c6-786d-45fc-a90e-48c7ffe03417    17544
# 87f82783-853b-417d-8964-b5cf11e44873    17544
# d241a044-0a06-40c2-9d90-c91fd0a95060    17544
# d7060523-b163-4cc3-bc94-970dac72a38a    17544
# fec52a19-9148-4350-a1b4-ae0da05ee199    17544
# Name: count, dtype: int64

# %%
df_final.describe()
# Out:
#             humidity          pm10           pm25       pressure  \
# count  192533.000000  142475.00000  142887.000000  192533.000000
# mean       52.706427      26.40624      14.096921     939.802395
# std        15.739595      49.61000      26.306709      12.804769
# min         9.500000       0.00000       0.000000     869.000000
# 25%        40.750000       5.25000       2.250000     937.000000
# 50%        53.562500      10.75000       5.500000     942.000000
# 75%        64.937500      26.00000      14.000000     946.000000
# max        99.000000    1995.00000     639.250000     971.750000
#
#          temperature     wind_speed  neighbor1_humidity  neighbor2_humidity  \
# count  192533.000000  192907.000000       192533.000000       192533.000000
# mean       16.796424       6.075865           52.234773           53.623165
# std         9.168444       3.743897           15.784644           16.410186
# min       -12.000000       0.000000            9.500000            9.500000
# 25%         9.666667       3.500000           40.354167           41.314815
# 50%        16.000000       5.300000           53.000000           54.468750
# 75%        23.750000       7.744444           64.250000           66.000000
# max        47.500000      32.800000           99.000000           99.000000
#
#        neighbor3_humidity  neighbor1_pressure  neighbor2_pressure  \
# count       192533.000000       192533.000000       192533.000000
# mean            51.226443          943.013828          942.099091
# std             15.056326            6.656861            6.732900
# min              9.500000          911.000000          911.000000
# 25%             39.750000          939.000000          938.000000
# 50%             52.250000          943.000000          942.000000
# 75%             63.000000          947.000000          946.000000
# max             86.750000          971.750000          971.750000
#
#        neighbor3_pressure  neighbor1_temperature  neighbor2_temperature  \
# count       192533.000000          192533.000000          192533.000000
# mean           942.391355              16.945689              16.705565
# std              6.431512               9.142617               9.149102
# min            916.400000             -12.000000             -12.000000
# 25%            938.183333               9.895833               9.533333
# 50%            942.000000              16.000000              16.000000
# 75%            946.000000              24.000000              23.500000
# max            971.750000              47.500000              45.500000
#
#        neighbor3_temperature  neighbor1_wind_speed  neighbor2_wind_speed  \
# count          192533.000000         192907.000000         192907.000000
# mean               17.260901              6.190128              6.174232
# std                 9.229391              3.863706              3.866399
# min               -12.000000              0.000000              0.000000
# 25%                10.000000              3.500000              3.500000
# 50%                16.364583              5.400000              5.400000
# 75%                24.125000              7.900000              7.900000
# max                47.500000             32.800000             32.800000
#
#        neighbor3_wind_speed
# count         192907.000000
# mean               6.158097
# std                3.849372
# min                0.000000
# 25%                3.500000
# 50%                5.400000
# 75%                7.900000
# max               32.800000

# %% [markdown]
# ### Function for extracting time features

# %%
def extract_time_features(df, timestamp_col='timestamp'):
    
    month = df[timestamp_col].dt.month

    df['season'] = np.select(
        [
            month.isin([12, 1, 2]),
            month.isin([3, 4, 5]),
            month.isin([6, 7, 8]),
            month.isin([9, 10, 11])
        ],
        [
            'winter',
            'spring',
            'summer',
            'autumn'
        ]
    )

    df['hour_sin'] = np.sin(2 * np.pi * df[timestamp_col].dt.hour / 24)
    df['hour_cos'] = np.cos(2 * np.pi * df[timestamp_col].dt.hour / 24)


    df['month_sin'] = np.sin(2 * np.pi * (df[timestamp_col].dt.month - 1) / 12)
    df['month_cos'] = np.cos(2 * np.pi * (df[timestamp_col].dt.month - 1) / 12)
    
    df['day_sin'] = np.sin(2 * np.pi * df[timestamp_col].dt.dayofweek / 7)
    df['day_cos'] = np.cos(2 * np.pi * df[timestamp_col].dt.dayofweek / 7)


    df['is_weekend'] = df[timestamp_col].dt.dayofweek.isin([5, 6]).astype(int)

    df['is_heating_season'] = df[timestamp_col].dt.month.isin([11, 12, 1, 2, 3]).astype(int)

    return df

# %%
df_final = extract_time_features(df_final)

# %%
df_final.head(20)
# Out:
#                    timestamp                              sensorId   humidity  \
# 0  2023-12-01 00:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  58.333333
# 1  2023-12-01 01:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.250000
# 2  2023-12-01 02:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  60.000000
# 3  2023-12-01 03:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.250000
# 4  2023-12-01 04:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.500000
# 5  2023-12-01 05:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  60.250000
# 6  2023-12-01 06:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.000000
# 7  2023-12-01 07:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  56.500000
# 8  2023-12-01 08:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  53.666667
# 9  2023-12-01 09:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  51.500000
# 10 2023-12-01 10:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  46.750000
# 11 2023-12-01 11:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  42.000000
# 12 2023-12-01 12:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  41.750000
# 13 2023-12-01 13:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  42.500000
# 14 2023-12-01 14:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  44.333333
# 15 2023-12-01 15:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  46.250000
# 16 2023-12-01 16:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  48.250000
# 17 2023-12-01 17:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  49.500000
# 18 2023-12-01 18:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  49.250000
# 19 2023-12-01 19:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  52.750000
#
#          pm10       pm25  pressure  temperature  wind_speed  \
# 0   28.333333  13.666667    943.00    12.000000         8.3
# 1   13.750000   5.000000    943.00    12.000000         9.3
# 2   10.000000   4.500000    942.50    12.250000         8.3
# 3    9.750000   4.500000    942.00    13.000000         9.4
# 4    5.000000   2.000000    942.00    13.000000         9.0
# 5    9.000000   4.000000    942.00    13.000000         7.6
# 6    8.000000   3.750000    942.00    13.750000         6.8
# 7   15.500000   7.000000    943.00    15.500000        12.4
# 8    7.333333   2.333333    943.00    16.666667        15.6
# 9    6.500000   1.750000    943.00    17.250000        18.6
# 10        NaN        NaN    942.50    18.125000        18.4
# 11   4.000000   1.000000    942.00    19.000000        18.2
# 12   7.000000   1.250000    941.75    19.500000        18.3
# 13  13.500000   1.250000    941.00    19.750000        17.6
# 14   6.000000   1.333333    941.00    19.000000        15.0
# 15   7.000000   1.500000    941.00    18.500000        12.6
# 16  10.250000   1.500000    941.00    18.000000        12.6
# 17  16.250000   2.250000    941.00    17.500000        10.4
# 18  11.666667   1.666667    941.00    17.000000         9.7
# 19  12.000000   2.500000    941.00    16.500000         9.4
#
#     neighbor1_humidity  neighbor2_humidity  ...  neighbor3_wind_speed  season  \
# 0            63.645833           63.645833  ...                  6.98  winter
# 1            64.750000           64.750000  ...                  7.50  winter
# 2            65.312500           65.312500  ...                  6.74  winter
# 3            64.854167           64.854167  ...                  7.84  winter
# 4            65.062500           65.062500  ...                  8.32  winter
# 5            66.500000           66.500000  ...                  6.28  winter
# 6            66.187500           66.187500  ...                  5.16  winter
# 7            63.250000           63.250000  ...                  8.72  winter
# 8            59.708333           59.708333  ...                 11.40  winter
# 9            55.062500           55.062500  ...                 14.72  winter
# 10           44.979167           44.979167  ...                 15.36  winter
# 11           44.562500           44.562500  ...                 14.80  winter
# 12           43.062500           43.062500  ...                 14.90  winter
# 13           44.312500           44.312500  ...                 13.84  winter
# 14           46.458333           46.458333  ...                 11.28  winter
# 15           48.187500           48.187500  ...                 10.36  winter
# 16           50.875000           50.875000  ...                 10.44  winter
# 17           54.000000           54.000000  ...                  8.84  winter
# 18           55.770833           55.770833  ...                  8.30  winter
# 19           57.062500           57.062500  ...                  8.28  winter
#
#         hour_sin      hour_cos  month_sin  month_cos   day_sin   day_cos  \
# 0   0.000000e+00  1.000000e+00       -0.5   0.866025 -0.433884 -0.900969
# 1   2.588190e-01  9.659258e-01       -0.5   0.866025 -0.433884 -0.900969
# 2   5.000000e-01  8.660254e-01       -0.5   0.866025 -0.433884 -0.900969
# 3   7.071068e-01  7.071068e-01       -0.5   0.866025 -0.433884 -0.900969
# 4   8.660254e-01  5.000000e-01       -0.5   0.866025 -0.433884 -0.900969
# 5   9.659258e-01  2.588190e-01       -0.5   0.866025 -0.433884 -0.900969
# 6   1.000000e+00  6.123234e-17       -0.5   0.866025 -0.433884 -0.900969
# 7   9.659258e-01 -2.588190e-01       -0.5   0.866025 -0.433884 -0.900969
# 8   8.660254e-01 -5.000000e-01       -0.5   0.866025 -0.433884 -0.900969
# 9   7.071068e-01 -7.071068e-01       -0.5   0.866025 -0.433884 -0.900969
# 10  5.000000e-01 -8.660254e-01       -0.5   0.866025 -0.433884 -0.900969
# 11  2.588190e-01 -9.659258e-01       -0.5   0.866025 -0.433884 -0.900969
# 12  1.224647e-16 -1.000000e+00       -0.5   0.866025 -0.433884 -0.900969
# 13 -2.588190e-01 -9.659258e-01       -0.5   0.866025 -0.433884 -0.900969
# 14 -5.000000e-01 -8.660254e-01       -0.5   0.866025 -0.433884 -0.900969
# 15 -7.071068e-01 -7.071068e-01       -0.5   0.866025 -0.433884 -0.900969
# 16 -8.660254e-01 -5.000000e-01       -0.5   0.866025 -0.433884 -0.900969
# 17 -9.659258e-01 -2.588190e-01       -0.5   0.866025 -0.433884 -0.900969
# 18 -1.000000e+00 -1.836970e-16       -0.5   0.866025 -0.433884 -0.900969
# 19 -9.659258e-01  2.588190e-01       -0.5   0.866025 -0.433884 -0.900969
#
#     is_weekend  is_heating_season
# 0            0                  1
# 1            0                  1
# 2            0                  1
# 3            0                  1
# 4            0                  1
# 5            0                  1
# 6            0                  1
# 7            0                  1
# 8            0                  1
# 9            0                  1
# 10           0                  1
# 11           0                  1
# 12           0                  1
# 13           0                  1
# 14           0                  1
# 15           0                  1
# 16           0                  1
# 17           0                  1
# 18           0                  1
# 19           0                  1
#
# [20 rows x 29 columns]

# %%
df_final.isnull().sum()
# Out:
# timestamp                    0
# sensorId                     0
# humidity                   451
# pm10                     50509
# pm25                     50097
# pressure                   451
# temperature                451
# wind_speed                  77
# neighbor1_humidity         451
# neighbor2_humidity         451
# neighbor3_humidity         451
# neighbor1_pressure         451
# neighbor2_pressure         451
# neighbor3_pressure         451
# neighbor1_temperature      451
# neighbor2_temperature      451
# neighbor3_temperature      451
# neighbor1_wind_speed        77
# neighbor2_wind_speed        77
# neighbor3_wind_speed        77
# season                       0
# hour_sin                     0
# hour_cos                     0
# month_sin                    0
# month_cos                    0
# day_sin                      0
# day_cos                      0
# is_weekend                   0
# is_heating_season            0
# dtype: int64

# %%
df_final.to_csv("../data/training/bitola_final_data.csv", index=False)
