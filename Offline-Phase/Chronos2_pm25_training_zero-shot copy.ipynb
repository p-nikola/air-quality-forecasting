# %%
# %pip install chronos-forecasting
# %pip install transformers accelerate
# Out:
# Requirement already satisfied: chronos-forecasting in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: accelerate<2,>=0.34 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from chronos-forecasting) (1.13.0)
# Requirement already satisfied: einops<1,>=0.7.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from chronos-forecasting) (0.8.2)
# Requirement already satisfied: numpy<3,>=1.21 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from chronos-forecasting) (1.26.4)
# Requirement already satisfied: scikit-learn<2,>=1.6.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from chronos-forecasting) (1.7.2)
# Requirement already satisfied: torch<3,>=2.2 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from chronos-forecasting) (2.9.1)
# Requirement already satisfied: transformers<5,>=4.41 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from chronos-forecasting) (4.57.6)
# Requirement already satisfied: packaging>=20.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from accelerate<2,>=0.34->chronos-forecasting) (26.2)
# Requirement already satisfied: psutil in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from accelerate<2,>=0.34->chronos-forecasting) (7.1.3)
# Requirement already satisfied: pyyaml in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from accelerate<2,>=0.34->chronos-forecasting) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from accelerate<2,>=0.34->chronos-forecasting) (0.36.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from accelerate<2,>=0.34->chronos-forecasting) (0.7.0)
# Requirement already satisfied: scipy>=1.8.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from scikit-learn<2,>=1.6.0->chronos-forecasting) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from scikit-learn<2,>=1.6.0->chronos-forecasting) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from scikit-learn<2,>=1.6.0->chronos-forecasting) (3.6.0)
# Requirement already satisfied: filelock in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch<3,>=2.2->chronos-forecasting) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch<3,>=2.2->chronos-forecasting) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch<3,>=2.2->chronos-forecasting) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch<3,>=2.2->chronos-forecasting) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch<3,>=2.2->chronos-forecasting) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch<3,>=2.2->chronos-forecasting) (2026.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers<5,>=4.41->chronos-forecasting) (2026.4.4)
# Requirement already satisfied: requests in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers<5,>=4.41->chronos-forecasting) (2.33.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers<5,>=4.41->chronos-forecasting) (0.22.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers<5,>=4.41->chronos-forecasting) (4.67.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate<2,>=0.34->chronos-forecasting) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch<3,>=2.2->chronos-forecasting) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from jinja2->torch<3,>=2.2->chronos-forecasting) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (2026.4.22)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (4.57.6)
# Requirement already satisfied: accelerate in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (1.13.0)
# Requirement already satisfied: filelock in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers) (3.29.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers) (2026.4.4)
# Requirement already satisfied: requests in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers) (2.33.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: psutil in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from accelerate) (7.1.3)
# Requirement already satisfied: torch>=2.0.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from accelerate) (2.9.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->transformers) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->transformers) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->transformers) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->transformers) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: peft in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from peft) (26.2)
# Requirement already satisfied: psutil in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from peft) (7.1.3)
# Requirement already satisfied: pyyaml in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from peft) (6.0.3)
# Requirement already satisfied: torch>=1.13.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from peft) (2.9.1)
# Requirement already satisfied: transformers in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from peft) (4.57.6)
# Requirement already satisfied: tqdm in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from peft) (4.67.3)
# Requirement already satisfied: accelerate>=0.21.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from peft) (1.13.0)
# Requirement already satisfied: safetensors in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from peft) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from peft) (0.36.2)
# Requirement already satisfied: filelock in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (1.5.0)
# Requirement already satisfied: requests in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (2.33.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: regex!=2019.12.17 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers->peft) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from transformers->peft) (0.22.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/jovan/Documents/Kodovi/RNMP/Project/venv/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2026.4.22)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from chronos import Chronos2Pipeline
from sklearn.metrics import r2_score,mean_squared_error

# %%
df = pd.read_csv("../data/training/bitola_final_data.csv")
df.head()
# Out:
#                    timestamp                              sensorId   humidity  \
# 0  2023-12-01 00:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  58.333333
# 1  2023-12-01 01:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.250000
# 2  2023-12-01 02:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  60.000000
# 3  2023-12-01 03:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.250000
# 4  2023-12-01 04:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714  59.500000
#
#         pm10       pm25  pressure  temperature  wind_speed  \
# 0  28.333333  13.666667     943.0        12.00         8.3
# 1  13.750000   5.000000     943.0        12.00         9.3
# 2  10.000000   4.500000     942.5        12.25         8.3
# 3   9.750000   4.500000     942.0        13.00         9.4
# 4   5.000000   2.000000     942.0        13.00         9.0
#
#    neighbor1_humidity  neighbor2_humidity  ...  neighbor3_wind_speed  season  \
# 0           63.645833           63.645833  ...                  6.98  winter
# 1           64.750000           64.750000  ...                  7.50  winter
# 2           65.312500           65.312500  ...                  6.74  winter
# 3           64.854167           64.854167  ...                  7.84  winter
# 4           65.062500           65.062500  ...                  8.32  winter
#
#    hour_sin  hour_cos  month_sin  month_cos   day_sin   day_cos  is_weekend  \
# 0  0.000000  1.000000       -0.5   0.866025 -0.433884 -0.900969           0
# 1  0.258819  0.965926       -0.5   0.866025 -0.433884 -0.900969           0
# 2  0.500000  0.866025       -0.5   0.866025 -0.433884 -0.900969           0
# 3  0.707107  0.707107       -0.5   0.866025 -0.433884 -0.900969           0
# 4  0.866025  0.500000       -0.5   0.866025 -0.433884 -0.900969           0
#
#    is_heating_season
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
#
# [5 rows x 29 columns]

# %%
df.describe()
# Out:
#             humidity          pm10           pm25       pressure  \
# count  192533.000000  142475.00000  142887.000000  192533.000000
# mean       52.706427      26.40624      14.096921     939.802395
# std        15.739595      49.61000      26.306709      12.804769
# min         9.500000       0.00000       0.000000     869.000000
# 25%        40.750000       5.25000       2.250000     937.000000
# 50%        53.562500      10.75000       5.500000     942.000000
# 75%        64.937500      26.00000      14.000000     946.000000
# max        99.000000    1995.00000     639.250000     971.750000
#
#          temperature     wind_speed  neighbor1_humidity  neighbor2_humidity  \
# count  192533.000000  192907.000000       192533.000000       192533.000000
# mean       16.796424       6.075865           52.234773           53.623165
# std         9.168444       3.743897           15.784644           16.410186
# min       -12.000000       0.000000            9.500000            9.500000
# 25%         9.666667       3.500000           40.354167           41.314815
# 50%        16.000000       5.300000           53.000000           54.468750
# 75%        23.750000       7.744444           64.250000           66.000000
# max        47.500000      32.800000           99.000000           99.000000
#
#        neighbor3_humidity  neighbor1_pressure  ...  neighbor2_wind_speed  \
# count       192533.000000       192533.000000  ...         192907.000000
# mean            51.226443          943.013828  ...              6.174232
# std             15.056326            6.656861  ...              3.866399
# min              9.500000          911.000000  ...              0.000000
# 25%             39.750000          939.000000  ...              3.500000
# 50%             52.250000          943.000000  ...              5.400000
# 75%             63.000000          947.000000  ...              7.900000
# max             86.750000          971.750000  ...             32.800000
#
#        neighbor3_wind_speed      hour_sin      hour_cos      month_sin  \
# count         192907.000000  1.929840e+05  1.929840e+05  192984.000000
# mean               6.158097 -1.847380e-17 -5.550655e-17      -0.002785
# std                3.849372  7.071086e-01  7.071086e-01       0.706861
# min                0.000000 -1.000000e+00 -1.000000e+00      -1.000000
# 25%                3.500000 -7.071068e-01 -7.071068e-01      -0.500000
# 50%                5.400000  6.123234e-17 -6.123234e-17       0.000000
# 75%                7.900000  7.071068e-01  7.071068e-01       0.866025
# max               32.800000  1.000000e+00  1.000000e+00       1.000000
#
#           month_cos        day_sin        day_cos     is_weekend  \
# count  1.929840e+05  192984.000000  192984.000000  192984.000000
# mean  -3.554140e-03      -0.002997      -0.000684       0.287278
# std    7.073415e-01       0.707344       0.706866       0.452493
# min   -1.000000e+00      -0.974928      -0.900969       0.000000
# 25%   -8.660254e-01      -0.781831      -0.900969       0.000000
# 50%   -1.836970e-16       0.000000      -0.222521       0.000000
# 75%    5.000000e-01       0.781831       0.623490       1.000000
# max    1.000000e+00       0.974928       1.000000       1.000000
#
#        is_heating_season
# count      192984.000000
# mean            0.414501
# std             0.492637
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             1.000000
# max             1.000000
#
# [8 rows x 26 columns]

# %%
len(df)
# Out:
# 192984

# %%
df['sensorId'].value_counts()
# Out:
# sensorId
# 16836a55-7140-43e2-9a63-56fac5cba714    17544
# 2002                                    17544
# 23b735ef-a996-4a7f-9998-2aa7e78827b0    17544
# 2819ecbb-5de3-4092-aa1d-4ba3a8c40add    17544
# 40f081a6-4095-43f7-bffb-64e2af8c026e    17544
# 7b316592-8036-41e2-b8dc-b06b6a9afd54    17544
# 874ff9c6-786d-45fc-a90e-48c7ffe03417    17544
# 87f82783-853b-417d-8964-b5cf11e44873    17544
# d241a044-0a06-40c2-9d90-c91fd0a95060    17544
# d7060523-b163-4cc3-bc94-970dac72a38a    17544
# fec52a19-9148-4350-a1b4-ae0da05ee199    17544
# Name: count, dtype: int64

# %%
TARGET = 'pm25'
ID_COL = 'sensorId'
TIME_COL = 'timestamp'
PREDICTION_LENGTH = 512

# %%
df[TIME_COL] = pd.to_datetime(df[TIME_COL])

# %%
df
# Out:
#                        timestamp                              sensorId  \
# 0      2023-12-01 00:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 1      2023-12-01 01:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 2      2023-12-01 02:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 3      2023-12-01 03:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 4      2023-12-01 04:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# ...                          ...                                   ...
# 192979 2025-11-30 19:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 192980 2025-11-30 20:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 192981 2025-11-30 21:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 192982 2025-11-30 22:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 192983 2025-11-30 23:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
#
#          humidity       pm10       pm25  pressure  temperature  wind_speed  \
# 0       58.333333  28.333333  13.666667     943.0        12.00         8.3
# 1       59.250000  13.750000   5.000000     943.0        12.00         9.3
# 2       60.000000  10.000000   4.500000     942.5        12.25         8.3
# 3       59.250000   9.750000   4.500000     942.0        13.00         9.4
# 4       59.500000   5.000000   2.000000     942.0        13.00         9.0
# ...           ...        ...        ...       ...          ...         ...
# 192979  61.750000  11.250000   6.000000     942.0         9.00         5.9
# 192980  63.250000   9.000000   5.666667     942.0         9.00         5.7
# 192981  63.500000  12.000000   6.000000     942.5         8.25         5.8
# 192982  63.750000   3.250000   2.500000     943.0         7.75         5.6
# 192983  63.750000   1.750000   0.750000     943.0         7.00         6.2
#
#         neighbor1_humidity  neighbor2_humidity  ...  neighbor3_wind_speed  \
# 0                63.645833           63.645833  ...                  6.98
# 1                64.750000           64.750000  ...                  7.50
# 2                65.312500           65.312500  ...                  6.74
# 3                64.854167           64.854167  ...                  7.84
# 4                65.062500           65.062500  ...                  8.32
# ...                    ...                 ...  ...                   ...
# 192979           63.500000           86.500000  ...                  5.30
# 192980           63.750000           90.500000  ...                  5.40
# 192981           63.333333           94.333333  ...                  5.40
# 192982           63.750000           98.000000  ...                  5.00
# 192983           64.000000           98.000000  ...                  4.90
#
#         season  hour_sin  hour_cos  month_sin  month_cos   day_sin   day_cos  \
# 0       winter  0.000000  1.000000  -0.500000   0.866025 -0.433884 -0.900969
# 1       winter  0.258819  0.965926  -0.500000   0.866025 -0.433884 -0.900969
# 2       winter  0.500000  0.866025  -0.500000   0.866025 -0.433884 -0.900969
# 3       winter  0.707107  0.707107  -0.500000   0.866025 -0.433884 -0.900969
# 4       winter  0.866025  0.500000  -0.500000   0.866025 -0.433884 -0.900969
# ...        ...       ...       ...        ...        ...       ...       ...
# 192979  autumn -0.965926  0.258819  -0.866025   0.500000 -0.781831  0.623490
# 192980  autumn -0.866025  0.500000  -0.866025   0.500000 -0.781831  0.623490
# 192981  autumn -0.707107  0.707107  -0.866025   0.500000 -0.781831  0.623490
# 192982  autumn -0.500000  0.866025  -0.866025   0.500000 -0.781831  0.623490
# 192983  autumn -0.258819  0.965926  -0.866025   0.500000 -0.781831  0.623490
#
#         is_weekend  is_heating_season
# 0                0                  1
# 1                0                  1
# 2                0                  1
# 3                0                  1
# 4                0                  1
# ...            ...                ...
# 192979           1                  1
# 192980           1                  1
# 192981           1                  1
# 192982           1                  1
# 192983           1                  1
#
# [192984 rows x 29 columns]

# %%
context_df = df.groupby(ID_COL).apply(lambda x: x.iloc[:-PREDICTION_LENGTH]).reset_index(drop=True)
ground_truth_df = df.groupby(ID_COL).apply(lambda x: x.iloc[-PREDICTION_LENGTH:]).reset_index(drop=True)
# Out:
# /var/folders/18/8m8jfl3d72v4p728z2p8fn8c0000gn/T/ipykernel_24912/2320177275.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   context_df = df.groupby(ID_COL).apply(lambda x: x.iloc[:-PREDICTION_LENGTH]).reset_index(drop=True)
# /var/folders/18/8m8jfl3d72v4p728z2p8fn8c0000gn/T/ipykernel_24912/2320177275.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ground_truth_df = df.groupby(ID_COL).apply(lambda x: x.iloc[-PREDICTION_LENGTH:]).reset_index(drop=True)

# %%
ground_truth_df
# Out:
#                      timestamp                              sensorId  \
# 0    2025-11-09 16:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 1    2025-11-09 17:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 2    2025-11-09 18:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 3    2025-11-09 19:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# 4    2025-11-09 20:00:00+00:00  16836a55-7140-43e2-9a63-56fac5cba714
# ...                        ...                                   ...
# 5627 2025-11-30 19:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 5628 2025-11-30 20:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 5629 2025-11-30 21:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 5630 2025-11-30 22:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
# 5631 2025-11-30 23:00:00+00:00  fec52a19-9148-4350-a1b4-ae0da05ee199
#
#       humidity       pm10       pm25  pressure  temperature  wind_speed  \
# 0        71.25  44.500000  29.750000    944.00        16.00         5.1
# 1        72.00  32.333333  20.666667    944.00        16.00         5.6
# 2        73.00  26.750000  16.750000    944.25        15.75         1.5
# 3        73.75  10.500000   6.250000    945.00        15.00         4.5
# 4        73.25   9.500000   6.250000    945.00        15.00         4.0
# ...        ...        ...        ...       ...          ...         ...
# 5627     61.75  11.250000   6.000000    942.00         9.00         5.9
# 5628     63.25   9.000000   5.666667    942.00         9.00         5.7
# 5629     63.50  12.000000   6.000000    942.50         8.25         5.8
# 5630     63.75   3.250000   2.500000    943.00         7.75         5.6
# 5631     63.75   1.750000   0.750000    943.00         7.00         6.2
#
#       neighbor1_humidity  neighbor2_humidity  ...  neighbor3_wind_speed  \
# 0              68.250000           74.116667  ...                   5.1
# 1              70.250000           75.301667  ...                   5.6
# 2              70.500000           76.353333  ...                   1.5
# 3              71.000000           76.920476  ...                   4.5
# 4              71.666667           74.636243  ...                   4.0
# ...                  ...                 ...  ...                   ...
# 5627           63.500000           86.500000  ...                   5.3
# 5628           63.750000           90.500000  ...                   5.4
# 5629           63.333333           94.333333  ...                   5.4
# 5630           63.750000           98.000000  ...                   5.0
# 5631           64.000000           98.000000  ...                   4.9
#
#       season  hour_sin      hour_cos  month_sin  month_cos   day_sin  day_cos  \
# 0     autumn -0.866025 -5.000000e-01  -0.866025        0.5 -0.781831  0.62349
# 1     autumn -0.965926 -2.588190e-01  -0.866025        0.5 -0.781831  0.62349
# 2     autumn -1.000000 -1.836970e-16  -0.866025        0.5 -0.781831  0.62349
# 3     autumn -0.965926  2.588190e-01  -0.866025        0.5 -0.781831  0.62349
# 4     autumn -0.866025  5.000000e-01  -0.866025        0.5 -0.781831  0.62349
# ...      ...       ...           ...        ...        ...       ...      ...
# 5627  autumn -0.965926  2.588190e-01  -0.866025        0.5 -0.781831  0.62349
# 5628  autumn -0.866025  5.000000e-01  -0.866025        0.5 -0.781831  0.62349
# 5629  autumn -0.707107  7.071068e-01  -0.866025        0.5 -0.781831  0.62349
# 5630  autumn -0.500000  8.660254e-01  -0.866025        0.5 -0.781831  0.62349
# 5631  autumn -0.258819  9.659258e-01  -0.866025        0.5 -0.781831  0.62349
#
#       is_weekend  is_heating_season
# 0              1                  1
# 1              1                  1
# 2              1                  1
# 3              1                  1
# 4              1                  1
# ...          ...                ...
# 5627           1                  1
# 5628           1                  1
# 5629           1                  1
# 5630           1                  1
# 5631           1                  1
#
# [5632 rows x 29 columns]

# %%
forecast_df = pd.read_csv('../data/raw/bitola_forecast_weather.csv')
forecast_df
# Out:
#                  timestamp                              sensorId  humidity  \
# 0      2025-11-09 16:00:00  16836a55-7140-43e2-9a63-56fac5cba714        88
# 1      2025-11-09 17:00:00  16836a55-7140-43e2-9a63-56fac5cba714        90
# 2      2025-11-09 18:00:00  16836a55-7140-43e2-9a63-56fac5cba714        91
# 3      2025-11-09 19:00:00  16836a55-7140-43e2-9a63-56fac5cba714        91
# 4      2025-11-09 20:00:00  16836a55-7140-43e2-9a63-56fac5cba714        93
# ...                    ...                                   ...       ...
# 59285  2026-03-01 18:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        51
# 59286  2026-03-01 19:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        56
# 59287  2026-03-01 20:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        56
# 59288  2026-03-01 21:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        58
# 59289  2026-03-01 22:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        58
#
#        pressure  temperature  wind_speed
# 0         944.7         12.5         7.1
# 1         944.7         12.1         7.1
# 2         944.5         12.0         6.2
# 3         944.9         12.0         5.8
# 4         944.8         11.8         5.8
# ...         ...          ...         ...
# 59285     950.9          7.6         7.4
# 59286     950.7          6.5         6.2
# 59287     951.1          5.8         6.8
# 59288     951.2          5.2         6.9
# 59289     950.8          4.7         7.0
#
# [59290 rows x 6 columns]

# %%
neighbourhood_matrix = pd.read_csv('../data/neighbors_data/bitola_sensor_distances.csv')
valid_sensors = df['sensorId'].unique()
neighbors_df_clean = neighbourhood_matrix[
    (neighbourhood_matrix['sensor_id'].isin(valid_sensors)) &
    (neighbourhood_matrix['neighbor_id'].isin(valid_sensors))
].copy()

# %%
def append_neighbors(df_hourly, neighbors_df, weather_cols, k_search=20, k_keep=3):
    # 1. Standardize the neighbor list
    # Ensure we only take the top K based on distance
    neighbors_topk = (
        neighbors_df.sort_values(["sensor_id", "distance_km"])
        .groupby("sensor_id")
        .head(k_search)
        .copy()
    )

    # Track original distance rank
    neighbors_topk['dist_rank'] = neighbors_topk.groupby("sensor_id").cumcount() + 1

    # 2. Merge with main data
    # We use 'neighbor_id' from the matrix to match 'sensorId' in the hourly data
    neighbor_values = neighbors_topk.merge(
        df_hourly[['sensorId', 'timestamp'] + weather_cols],
        left_on='neighbor_id',
        right_on='sensorId',
        how='inner'
    )

    # 3. Filter for availability
    # The 'sensor_id' here is the ORIGINAL sensor we are finding neighbors for
    available_topk = (
        neighbor_values.sort_values(['sensor_id', 'timestamp', 'dist_rank'])
        .groupby(['sensor_id', 'timestamp'])
        .head(k_keep)
        .copy()
    )

    # Create the 1, 2, 3 rank for the wide-format columns
    available_topk['final_rank'] = available_topk.groupby(['sensor_id', 'timestamp']).cumcount() + 1

    # 4. Pivot to wide format
    pivot_df = available_topk.pivot(
        index=['sensor_id', 'timestamp'],
        columns='final_rank',
        values=weather_cols
    )

    # Clean up column names: neighbor1_temp, neighbor2_temp, etc.
    if isinstance(pivot_df.columns, pd.MultiIndex):
        pivot_df.columns = [f"neighbor{rank}_{col}" for col, rank in pivot_df.columns]
    else:
        # Handle case with only one weather column
        pivot_df.columns = [f"neighbor{i}_{weather_cols[0]}" for i in pivot_df.columns]

    pivot_df = pivot_df.reset_index()

    # 5. Final Join back to original data
    df_result = df_hourly.merge(
        pivot_df,
        left_on=['sensorId', 'timestamp'],
        right_on=['sensor_id', 'timestamp'],
        how='left'
    ).drop(columns=['sensor_id'])

    return df_result

# %%
weather_cols = ['humidity', 'pressure', 'temperature', 'wind_speed']

# %%
forecast_df = append_neighbors(forecast_df,neighbors_df_clean, weather_cols)
forecast_df
# Out:
#                  timestamp                              sensorId  humidity  \
# 0      2025-11-09 16:00:00  16836a55-7140-43e2-9a63-56fac5cba714        88
# 1      2025-11-09 17:00:00  16836a55-7140-43e2-9a63-56fac5cba714        90
# 2      2025-11-09 18:00:00  16836a55-7140-43e2-9a63-56fac5cba714        91
# 3      2025-11-09 19:00:00  16836a55-7140-43e2-9a63-56fac5cba714        91
# 4      2025-11-09 20:00:00  16836a55-7140-43e2-9a63-56fac5cba714        93
# ...                    ...                                   ...       ...
# 59285  2026-03-01 18:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        51
# 59286  2026-03-01 19:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        56
# 59287  2026-03-01 20:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        56
# 59288  2026-03-01 21:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        58
# 59289  2026-03-01 22:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        58
#
#        pressure  temperature  wind_speed  neighbor1_humidity  \
# 0         944.7         12.5         7.1                92.0
# 1         944.7         12.1         7.1                87.0
# 2         944.5         12.0         6.2                93.0
# 3         944.9         12.0         5.8                95.0
# 4         944.8         11.8         5.8                98.0
# ...         ...          ...         ...                 ...
# 59285     950.9          7.6         7.4                44.0
# 59286     950.7          6.5         6.2                52.0
# 59287     951.1          5.8         6.8                56.0
# 59288     951.2          5.2         6.9                59.0
# 59289     950.8          4.7         7.0                60.0
#
#        neighbor2_humidity  neighbor3_humidity  neighbor1_pressure  \
# 0                    88.0                92.0               942.4
# 1                    90.0                87.0               942.4
# 2                    91.0                93.0               942.2
# 3                    91.0                95.0               942.6
# 4                    93.0                98.0               942.5
# ...                   ...                 ...                 ...
# 59285                51.0                44.0               953.1
# 59286                56.0                52.0               953.0
# 59287                56.0                56.0               953.4
# 59288                58.0                59.0               953.6
# 59289                58.0                60.0               953.1
#
#        neighbor2_pressure  neighbor3_pressure  neighbor1_temperature  \
# 0                   944.9               945.4                   11.9
# 1                   945.0               945.4                   11.8
# 2                   944.8               945.2                   11.4
# 3                   945.1               945.5                   11.3
# 4                   945.0               945.5                   11.1
# ...                   ...                 ...                    ...
# 59285               949.3               953.3                    7.9
# 59286               949.1               953.2                    7.1
# 59287               949.4               953.6                    6.2
# 59288               949.6               953.8                    5.4
# 59289               949.2               953.3                    4.6
#
#        neighbor2_temperature  neighbor3_temperature  neighbor1_wind_speed  \
# 0                       12.5                   12.1                   4.0
# 1                       12.1                   12.0                   2.8
# 2                       12.0                   11.6                   3.9
# 3                       12.0                   11.5                   2.9
# 4                       11.8                   11.3                   3.8
# ...                      ...                    ...                   ...
# 59285                    7.5                    7.9                   5.9
# 59286                    6.4                    7.1                   4.5
# 59287                    5.7                    6.2                   4.9
# 59288                    5.1                    5.4                   4.6
# 59289                    4.6                    4.6                   4.4
#
#        neighbor2_wind_speed  neighbor3_wind_speed
# 0                       7.1                   4.0
# 1                       7.1                   2.8
# 2                       6.2                   3.9
# 3                       5.8                   2.9
# 4                       5.8                   3.8
# ...                     ...                   ...
# 59285                   7.4                   5.9
# 59286                   6.2                   4.5
# 59287                   6.8                   4.9
# 59288                   6.9                   4.6
# 59289                   7.0                   4.4
#
# [59290 rows x 18 columns]

# %%
def extract_time_features(df, timestamp_col='timestamp'):
    
    month = df[timestamp_col].dt.month

    df['season'] = np.select(
        [
            month.isin([12, 1, 2]),
            month.isin([3, 4, 5]),
            month.isin([6, 7, 8]),
            month.isin([9, 10, 11])
        ],
        [
            'winter',
            'spring',
            'summer',
            'autumn'
        ]
    )

    df['hour_sin'] = np.sin(2 * np.pi * df[timestamp_col].dt.hour / 24)
    df['hour_cos'] = np.cos(2 * np.pi * df[timestamp_col].dt.hour / 24)


    df['month_sin'] = np.sin(2 * np.pi * (df[timestamp_col].dt.month - 1) / 12)
    df['month_cos'] = np.cos(2 * np.pi * (df[timestamp_col].dt.month - 1) / 12)
    
    df['day_sin'] = np.sin(2 * np.pi * df[timestamp_col].dt.dayofweek / 7)
    df['day_cos'] = np.cos(2 * np.pi * df[timestamp_col].dt.dayofweek / 7)


    df['is_weekend'] = df[timestamp_col].dt.dayofweek.isin([5, 6]).astype(int)

    df['is_heating_season'] = df[timestamp_col].dt.month.isin([11, 12, 1, 2, 3]).astype(int)

    return df

# %%
forecast_df['timestamp'] = pd.to_datetime(forecast_df['timestamp'])
forecast_df = extract_time_features(forecast_df)
forecast_df
# Out:
#                 timestamp                              sensorId  humidity  \
# 0     2025-11-09 16:00:00  16836a55-7140-43e2-9a63-56fac5cba714        88
# 1     2025-11-09 17:00:00  16836a55-7140-43e2-9a63-56fac5cba714        90
# 2     2025-11-09 18:00:00  16836a55-7140-43e2-9a63-56fac5cba714        91
# 3     2025-11-09 19:00:00  16836a55-7140-43e2-9a63-56fac5cba714        91
# 4     2025-11-09 20:00:00  16836a55-7140-43e2-9a63-56fac5cba714        93
# ...                   ...                                   ...       ...
# 59285 2026-03-01 18:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        51
# 59286 2026-03-01 19:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        56
# 59287 2026-03-01 20:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        56
# 59288 2026-03-01 21:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        58
# 59289 2026-03-01 22:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        58
#
#        pressure  temperature  wind_speed  neighbor1_humidity  \
# 0         944.7         12.5         7.1                92.0
# 1         944.7         12.1         7.1                87.0
# 2         944.5         12.0         6.2                93.0
# 3         944.9         12.0         5.8                95.0
# 4         944.8         11.8         5.8                98.0
# ...         ...          ...         ...                 ...
# 59285     950.9          7.6         7.4                44.0
# 59286     950.7          6.5         6.2                52.0
# 59287     951.1          5.8         6.8                56.0
# 59288     951.2          5.2         6.9                59.0
# 59289     950.8          4.7         7.0                60.0
#
#        neighbor2_humidity  neighbor3_humidity  neighbor1_pressure  ...  \
# 0                    88.0                92.0               942.4  ...
# 1                    90.0                87.0               942.4  ...
# 2                    91.0                93.0               942.2  ...
# 3                    91.0                95.0               942.6  ...
# 4                    93.0                98.0               942.5  ...
# ...                   ...                 ...                 ...  ...
# 59285                51.0                44.0               953.1  ...
# 59286                56.0                52.0               953.0  ...
# 59287                56.0                56.0               953.4  ...
# 59288                58.0                59.0               953.6  ...
# 59289                58.0                60.0               953.1  ...
#
#        neighbor3_wind_speed  season  hour_sin      hour_cos  month_sin  \
# 0                       4.0  autumn -0.866025 -5.000000e-01  -0.866025
# 1                       2.8  autumn -0.965926 -2.588190e-01  -0.866025
# 2                       3.9  autumn -1.000000 -1.836970e-16  -0.866025
# 3                       2.9  autumn -0.965926  2.588190e-01  -0.866025
# 4                       3.8  autumn -0.866025  5.000000e-01  -0.866025
# ...                     ...     ...       ...           ...        ...
# 59285                   5.9  spring -1.000000 -1.836970e-16   0.866025
# 59286                   4.5  spring -0.965926  2.588190e-01   0.866025
# 59287                   4.9  spring -0.866025  5.000000e-01   0.866025
# 59288                   4.6  spring -0.707107  7.071068e-01   0.866025
# 59289                   4.4  spring -0.500000  8.660254e-01   0.866025
#
#        month_cos   day_sin  day_cos is_weekend  is_heating_season
# 0            0.5 -0.781831  0.62349          1                  1
# 1            0.5 -0.781831  0.62349          1                  1
# 2            0.5 -0.781831  0.62349          1                  1
# 3            0.5 -0.781831  0.62349          1                  1
# 4            0.5 -0.781831  0.62349          1                  1
# ...          ...       ...      ...        ...                ...
# 59285        0.5 -0.781831  0.62349          1                  1
# 59286        0.5 -0.781831  0.62349          1                  1
# 59287        0.5 -0.781831  0.62349          1                  1
# 59288        0.5 -0.781831  0.62349          1                  1
# 59289        0.5 -0.781831  0.62349          1                  1
#
# [59290 rows x 27 columns]

# %%
start = pd.Timestamp("2025-11-09 16:00:00")
end = pd.Timestamp("2025-12-01 00:00:00")

filtered_df = forecast_df[
    (forecast_df["timestamp"] >= start) &
    (forecast_df["timestamp"] < end)
]

# %%
filtered_df
# Out:
#                 timestamp                              sensorId  humidity  \
# 0     2025-11-09 16:00:00  16836a55-7140-43e2-9a63-56fac5cba714        88
# 1     2025-11-09 17:00:00  16836a55-7140-43e2-9a63-56fac5cba714        90
# 2     2025-11-09 18:00:00  16836a55-7140-43e2-9a63-56fac5cba714        91
# 3     2025-11-09 19:00:00  16836a55-7140-43e2-9a63-56fac5cba714        91
# 4     2025-11-09 20:00:00  16836a55-7140-43e2-9a63-56fac5cba714        93
# ...                   ...                                   ...       ...
# 57102 2025-11-30 19:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        88
# 57103 2025-11-30 20:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        85
# 57104 2025-11-30 21:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        84
# 57105 2025-11-30 22:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        86
# 57106 2025-11-30 23:00:00  fec52a19-9148-4350-a1b4-ae0da05ee199        85
#
#        pressure  temperature  wind_speed  neighbor1_humidity  \
# 0         944.7         12.5         7.1                92.0
# 1         944.7         12.1         7.1                87.0
# 2         944.5         12.0         6.2                93.0
# 3         944.9         12.0         5.8                95.0
# 4         944.8         11.8         5.8                98.0
# ...         ...          ...         ...                 ...
# 57102     940.4          4.3         5.3                92.0
# 57103     940.9          4.1         5.0                91.0
# 57104     941.2          3.9         5.0                92.0
# 57105     941.2          3.5         3.8                93.0
# 57106     941.7          3.2         4.2                90.0
#
#        neighbor2_humidity  neighbor3_humidity  neighbor1_pressure  ...  \
# 0                    88.0                92.0               942.4  ...
# 1                    90.0                87.0               942.4  ...
# 2                    91.0                93.0               942.2  ...
# 3                    91.0                95.0               942.6  ...
# 4                    93.0                98.0               942.5  ...
# ...                   ...                 ...                 ...  ...
# 57102                88.0                92.0               942.9  ...
# 57103                85.0                91.0               943.4  ...
# 57104                84.0                92.0               943.9  ...
# 57105                86.0                93.0               943.9  ...
# 57106                85.0                90.0               944.3  ...
#
#        neighbor3_wind_speed  season  hour_sin      hour_cos  month_sin  \
# 0                       4.0  autumn -0.866025 -5.000000e-01  -0.866025
# 1                       2.8  autumn -0.965926 -2.588190e-01  -0.866025
# 2                       3.9  autumn -1.000000 -1.836970e-16  -0.866025
# 3                       2.9  autumn -0.965926  2.588190e-01  -0.866025
# 4                       3.8  autumn -0.866025  5.000000e-01  -0.866025
# ...                     ...     ...       ...           ...        ...
# 57102                   0.8  autumn -0.965926  2.588190e-01  -0.866025
# 57103                   2.1  autumn -0.866025  5.000000e-01  -0.866025
# 57104                   0.5  autumn -0.707107  7.071068e-01  -0.866025
# 57105                   0.4  autumn -0.500000  8.660254e-01  -0.866025
# 57106                   2.6  autumn -0.258819  9.659258e-01  -0.866025
#
#        month_cos   day_sin  day_cos is_weekend  is_heating_season
# 0            0.5 -0.781831  0.62349          1                  1
# 1            0.5 -0.781831  0.62349          1                  1
# 2            0.5 -0.781831  0.62349          1                  1
# 3            0.5 -0.781831  0.62349          1                  1
# 4            0.5 -0.781831  0.62349          1                  1
# ...          ...       ...      ...        ...                ...
# 57102        0.5 -0.781831  0.62349          1                  1
# 57103        0.5 -0.781831  0.62349          1                  1
# 57104        0.5 -0.781831  0.62349          1                  1
# 57105        0.5 -0.781831  0.62349          1                  1
# 57106        0.5 -0.781831  0.62349          1                  1
#
# [11264 rows x 27 columns]

# %%
print("Loading Chronos-2 and generating forecasts...")
pipeline = Chronos2Pipeline.from_pretrained(
    "chronos2_zero_shot"
)
# Out:
# Loading Chronos-2 and generating forecasts...

# %%
filtered_df['humidity'] = filtered_df['humidity'].astype(float)
# Out:
# /var/folders/18/8m8jfl3d72v4p728z2p8fn8c0000gn/T/ipykernel_24912/1051234344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['humidity'] = filtered_df['humidity'].astype(float)

# %%
filtered_df['sensorId'].unique()
# Out:
# array(['16836a55-7140-43e2-9a63-56fac5cba714', '2001', '2002',
#        '23b735ef-a996-4a7f-9998-2aa7e78827b0',
#        '24039f11-a4fc-4b2d-8bc0-6fd36059f117',
#        '2819ecbb-5de3-4092-aa1d-4ba3a8c40add',
#        '30dab8a6-ff63-43ce-9a3b-99f1f3f7054d',
#        '40f081a6-4095-43f7-bffb-64e2af8c026e',
#        '692c454c-a1ad-41fa-b3ca-aa1cb7d55d30',
#        '7b316592-8036-41e2-b8dc-b06b6a9afd54',
#        '874ff9c6-786d-45fc-a90e-48c7ffe03417',
#        '87f82783-853b-417d-8964-b5cf11e44873',
#        'a17013e7-8d1d-4b0d-8e2f-e0881dbca3ac',
#        'a9a2083f-f086-4fae-bdae-355b391f436b',
#        'be427cee-4c3a-4aa2-a1ce-9795a74533be',
#        'c3f3da9b-9fd3-4037-94d3-598d655e6be9',
#        'd241a044-0a06-40c2-9d90-c91fd0a95060',
#        'd7060523-b163-4cc3-bc94-970dac72a38a',
#        'd851c0b9-990e-41db-9c53-529f88524cf9',
#        'e20e9778-a020-4b86-932a-b7ab6a713a00',
#        'ece1058a-ecab-4736-872f-790145aaadfe',
#        'fec52a19-9148-4350-a1b4-ae0da05ee199'], dtype=object)

# %%
context_df['sensorId'].unique()
# Out:
# array(['16836a55-7140-43e2-9a63-56fac5cba714', '2002',
#        '23b735ef-a996-4a7f-9998-2aa7e78827b0',
#        '2819ecbb-5de3-4092-aa1d-4ba3a8c40add',
#        '40f081a6-4095-43f7-bffb-64e2af8c026e',
#        '7b316592-8036-41e2-b8dc-b06b6a9afd54',
#        '874ff9c6-786d-45fc-a90e-48c7ffe03417',
#        '87f82783-853b-417d-8964-b5cf11e44873',
#        'd241a044-0a06-40c2-9d90-c91fd0a95060',
#        'd7060523-b163-4cc3-bc94-970dac72a38a',
#        'fec52a19-9148-4350-a1b4-ae0da05ee199'], dtype=object)

# %%
future_df = filtered_df[
    filtered_df["sensorId"].isin(context_df["sensorId"].unique())
].copy()

# %%
max(future_df['timestamp'])
# Out:
# Timestamp('2025-11-30 23:00:00')

# %%
forecast_df = pipeline.predict_df(
    df=context_df,
    prediction_length=PREDICTION_LENGTH,
    target=TARGET,
    id_column=ID_COL,
    future_df = future_df,
    validate_inputs=False
)

# %%
# Merge predictions with actual values to align them
eval_df = pd.merge(
    forecast_df[[ID_COL, TIME_COL, 'predictions']],
    ground_truth_df[[ID_COL, TIME_COL, TARGET]],
    on=[ID_COL, TIME_COL]
)

# %%
eval_df.columns
# Out:
# Index(['sensorId', 'timestamp', 'predictions', 'pm25'], dtype='object')

# %%
eval_df
# Out:
#                                   sensorId                 timestamp  \
# 0     16836a55-7140-43e2-9a63-56fac5cba714 2025-11-09 16:00:00+00:00
# 1     16836a55-7140-43e2-9a63-56fac5cba714 2025-11-09 17:00:00+00:00
# 2     16836a55-7140-43e2-9a63-56fac5cba714 2025-11-09 18:00:00+00:00
# 3     16836a55-7140-43e2-9a63-56fac5cba714 2025-11-09 19:00:00+00:00
# 4     16836a55-7140-43e2-9a63-56fac5cba714 2025-11-09 20:00:00+00:00
# ...                                    ...                       ...
# 5627  fec52a19-9148-4350-a1b4-ae0da05ee199 2025-11-30 19:00:00+00:00
# 5628  fec52a19-9148-4350-a1b4-ae0da05ee199 2025-11-30 20:00:00+00:00
# 5629  fec52a19-9148-4350-a1b4-ae0da05ee199 2025-11-30 21:00:00+00:00
# 5630  fec52a19-9148-4350-a1b4-ae0da05ee199 2025-11-30 22:00:00+00:00
# 5631  fec52a19-9148-4350-a1b4-ae0da05ee199 2025-11-30 23:00:00+00:00
#
#       predictions       pm25
# 0       24.697124  29.750000
# 1       24.568405  20.666667
# 2       23.368343  16.750000
# 3       21.584959   6.250000
# 4       19.764832   6.250000
# ...           ...        ...
# 5627     2.049600   6.000000
# 5628     1.543457   5.666667
# 5629     1.139679   6.000000
# 5630     0.876802   2.500000
# 5631     0.723666   0.750000
#
# [5632 rows x 4 columns]

# %%
from pathlib import Path
import sqlite3

DB_PATH = Path("../data/project.db")
if not DB_PATH.exists():
    DB_PATH = Path("data/project.db")

if not DB_PATH.exists():
    raise FileNotFoundError("Could not find data/project.db. Run the notebook from offline-Phase or the project root.")

CITY = "Bitola"
MODEL_VERSION = f"chronos2_{TARGET}_bitola_offline_test_{PREDICTION_LENGTH}h"
MODEL_TYPE = 'zero_shot'
train_df = (
    context_df.rename(
        columns={
            ID_COL: "sensor_id",
            TARGET: "actual_value"
        }
    )
)
train_df['predicted_value'] = np.nan
test_df = (
    eval_df
    .rename(columns={
        ID_COL:"sensor_id",
        TARGET: "actual_value",
        "predictions": "predicted_value",
    })
)
offline_results = pd.concat([train_df,test_df],ignore_index=True).sort_values(["sensor_id", "timestamp"])
offline_results = offline_results[["sensor_id", "timestamp", "actual_value", "predicted_value"]].copy()
offline_results["city"] = CITY
offline_results["pollutant"] = TARGET
offline_results["model_version"] = MODEL_VERSION
offline_results["model_type"] = MODEL_TYPE
offline_results["timestamp"] = pd.to_datetime(offline_results["timestamp"]).dt.strftime("%Y-%m-%d %H:%M:%S")
offline_results = offline_results[["city", "sensor_id", "timestamp", "pollutant", "actual_value", "predicted_value", "model_version","model_type"]]

records = list(offline_results.itertuples(index=False, name=None))

with sqlite3.connect(DB_PATH) as conn:
    conn.execute("""
        CREATE TABLE IF NOT EXISTS offline_test_results (
            city TEXT NOT NULL,
            sensor_id TEXT NOT NULL,
            timestamp TEXT NOT NULL,
            pollutant TEXT NOT NULL,
            actual_value REAL,
            predicted_value REAL,
            model_version TEXT,
            model_type TEXT,
            PRIMARY KEY (city, sensor_id, timestamp, pollutant)
        )
    """)
    conn.executemany("""
        INSERT OR REPLACE INTO offline_test_results (
            city, sensor_id, timestamp, pollutant, actual_value, predicted_value, model_version,model_type
        ) VALUES (?, ?, ?, ?, ?, ?, ?,?)
    """, records)

print(f"Saved {len(records)} {CITY} {TARGET} offline test rows to {DB_PATH}")

# %%
eval_df.dropna(axis=0,inplace=True)

# %%
eval_df.isnull().sum()
# Out:
# sensorId       0
# timestamp      0
# predictions    0
# pm25           0
# dtype: int64

# %%
y_true = eval_df['pm25']
y_pred = eval_df['predictions']

# %%
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)

print(f"--- Global Model Evaluation ---")
print(f"RMSE: {rmse:.4f}")
print(f"R2:   {r2:.4f}")
# Out:
# --- Global Model Evaluation ---
# RMSE: 15.8616
# R2:   0.3285

# %%
per_sensor = eval_df.groupby(ID_COL).apply(
    lambda df: pd.Series({
        "r2": r2_score(df["pm25"], df["predictions"]),
        "rmse": np.sqrt(mean_squared_error(df["pm25"], df["predictions"]))
    }),
    include_groups=False
)

print(per_sensor)
# Out:
#                                             r2       rmse
# sensorId
# 16836a55-7140-43e2-9a63-56fac5cba714  0.116175   6.366199
# 2002                                  0.153241  18.584596
# 23b735ef-a996-4a7f-9998-2aa7e78827b0  0.055982  21.849131
# 2819ecbb-5de3-4092-aa1d-4ba3a8c40add  0.071795   4.889936
# 40f081a6-4095-43f7-bffb-64e2af8c026e -0.008845  14.345157
# 7b316592-8036-41e2-b8dc-b06b6a9afd54  0.261500  27.463314
# 874ff9c6-786d-45fc-a90e-48c7ffe03417  0.060239  11.309507
# 87f82783-853b-417d-8964-b5cf11e44873  0.222030  24.962356
# d241a044-0a06-40c2-9d90-c91fd0a95060 -0.099914   1.747426
# d7060523-b163-4cc3-bc94-970dac72a38a  0.091174  12.515651
# fec52a19-9148-4350-a1b4-ae0da05ee199  0.168303   3.634965
